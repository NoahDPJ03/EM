# %% [markdown]
# **Expectation Maximization: Responsibility method and Monte Carlo Markov Chain Method**
#
# Expectation Maximization (EM) is an algorithm designed for finding the mixes of a certain dataset. A mixed dataset means that data points can cmoe from different distributions. For EM to work, we need to know two things about the data:
#
# 1. How many distributions are associated with the dat
# 2. What those distributions are
#
# For example, say we have a dataset call $H$ that is mixed with a Normal, Exponential, and Uniform distribution. We would need to know that there are 3 distributions and that those distributions are a Normal, Exponential, and a Uniform.
#
# There are multiple steps to this algorithm work, in which I will explain each one:
#
# 1. Initialization, we set each mixture component weight, called $\pi_j$ for distribution $j$ to a value $\in [0,1]$ such that all the mixture components added together $= 1$ (so basically a probability distribution of distributions). We also set initial parameters for all the distributions.
#
# 2. We repeat the following steps until we reach convergence or we have reached the number of iterations desired
#
# 3. The E-step: We use what we know about the data points, the weights of the distributions, and the pdf's associated with each distributions to give us probabililies that a data point came from a particular distribution, or the number of samples from a particular distribution run
#
# 4. The M-step: We update the mixing weights by averaging the probabilities that a data point come from a particular distribution over all data points for each component.
#
# 5. We check for convergence or if we reached number of iterations.
#
# There are two strategies in doing Expectation Maximization, and my goal is to analyze each strategy and to look at the pros and cons of each.
#
# I will start by explaining the first method which if by computing responsibilities (Normal Method of EM). Responsibilities are the probabililies that a data point came from a particular distribution. I didn't want to say this at the start because the other strategy doesn't use responsibilities, so I thought it would confuse some.
#
# The difference between the strategies is how they change in the E-step and M-step. For the normal method, once we have initialized everything, our E-step goes as follows:
# Compute:
#
# $$
# \gamma_{ij} = P(z_i = j \mid x_i, \theta) = \frac{\pi_j \cdot f_j(x_i)}{\sum_k \pi_k \cdot f_k(x_i)}
# $$
#
#  for all combinations or a data point and distribution
#
# Where $\gamma_{ij}$ is the responsibility or probability that data point $x_i$ came from the distribution $j$.
#
# We then do the M-step for Normal EM, which is:
#
# Update the mixture weights by taking the average over all responsibilities associated with mixture $j$, or:
#
# $$
# \pi_j = \frac{1}{n} \sum_{i=1}^{n} \gamma_{ij} \quad
# $$
#
# For an intuitional sense, imagine that we acquire a responsibility super high associated with a data point and distribution (which likely means that the pdf value at the data point was high with respect to the others). This means that the probability the x_i is associated with that distribution is high. Since this is true, it would increase our mixture amount because we have a data point that is extremely "connected" to that certain distribution.
#
# The next method is the point in which this project came to fruition in the first place.
#
# The Expection Maximization Monte Carlo Method
#
# This is supposed to approximate the responsibility, or normal EM. The reason why someone may do such a method is because the calculations for the responsibilities may be hard to compute.
#
# You approximate the responsibilites by sampling in Monte Carlo style: for all the data points, make a Monte Carlo Markov Chain over for however many iterations, and basing our decision to go to a different node, or more specifically, making an educated guess on what distribution this data point comes from by using the acceptance ratio:
# $$
# \alpha = \min\left(1, \frac{\pi_{z_{\text{new}}} \cdot f_{z_{\text{new}}}(x)}{\pi_{z} \cdot f_{z}(x)} \right)
# $$
# What this becomes are samples of each data point, and for our M-step we look at all the different samples, and compute:
#
# $$
#  \pi_j = \frac{\text{number of samples where we get distribution $j$} }{\text{total number of samples}}
# $$
#
# Methods
#
# For my methods in analyzing these two methods, I will first start by implementing them into python and give a couple miniature examples of a mixed dataset and see how these methods favor. I will produce my own dataset to which I know all the true information of: The mixing weights, parameters, distributions, etc. and compare that as well to the results that both methods got.
#
# Later on, we will create a random mixing distribution sampler where it creates mixes of distribution sizing from 2 to 8 mixes. The parameters will all be random in a certain predetermined interval for each.
#
# To start, we must implement each Method, to which I have done so here:
#
# The first I did was the MCMC method...

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import math
import functools

#EM MCl#########################################################################
################################################################################
################################################################################
################################################################################
################################################################################

def pick_distribution(answer):

  if answer == "Uniform":
    while True:
      try:
        a0 = float(input("Initial lower bound guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")
    while True:
      try:
        b0 = float(input("Initial upper bound guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")
    def pdf(x):
      return 1 / (b0 - a0) if a0 <= x <= b0 else 0

    return pdf, (a0, b0)

  if answer == "Exponential":
    while True:
      try:
        theta0 = float(input("Enter the mean guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")

    def pdf(x):
      return (1 / theta0) * math.exp(-x / theta0) if x >= 0 else 0

    return pdf, (theta0,) # Corrected parameter return

  if answer == "Normal":
    while True:
      try:
        mu0 = float(input("Enter the mean guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")
    while True:
      try:
        sigma0 = float(input("Enter the standard deviation guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")
    def pdf(x_val):
      return (1 / (sigma0 * math.sqrt(2 * math.pi))) * math.exp(-(x_val - mu0)**2 / (2 * sigma0**2))
    return pdf, (mu0, sigma0)

  if answer == "Bernoulli":
    while True:
        try:
            p = float(input("Enter probability of success (0 < p < 1): "))
            if 0 < p < 1:
                break
            else:
                print("p must be between 0 and 1.")
        except ValueError:
            print("Invalid input. Please enter a number.")

    def pdf(x):
        return p if x == 1 else (1 - p) if x == 0 else 0

    return pdf, (p,)

  if answer == "Poisson":

    integer_data = [x for x in data if float(x).is_integer()]
    estimated_lambda = np.mean(integer_data) if integer_data else 3.0

    print(f"Suggested lambda (from integer data): {estimated_lambda:.2f}")
    while True:
        try:
            lambda_val = float(input("Enter the Poisson mean (lambda): "))
            if lambda_val > 0:
                break
            else:
                print("lambda must be greater than 0.")
        except ValueError:
            print("Invalid input. Please enter a number.")
    def pdf(x):
      if x >= 0 and float(x).is_integer():
          return (math.exp(-lambda_val) * (lambda_val ** x)) / math.factorial(int(x)) # Corrected condition and factorial input
      else:
          return 0

    return pdf, (lambda_val,)


  # More distributions TBC

def e_step_MCMC(data, components, steps = 100):
  n = len(data)
  k = len(components)

  z_samples = []

  for i in range(n):
    x = data[i]

    z = np.random.choice(k)

    chain = []

    for t in range(steps):
      if k > 1: # Add check for k > 1
        z_new = np.random.choice([j for j in range(k) if j != z])

        if components[z_new]["distr name"] == "Poisson" and not float(x).is_integer():
          continue
        if components[z_new]["distr name"] == "Bernoulli" and not float(x).is_integer():
          continue

        num = components[z_new]["pi"] * components[z_new]["pdf"](x) # Score function which will idealize the data point with a certain distribution if the associated pi and pdf value
        den = components[z]["pi"] * components[z]["pdf"](x)         # with the data point is more than that of the previous

        alpha = min(1, num / den if den > 0 else 1)

        if np.random.rand() < alpha:
          z = z_new

      chain.append(z)

    z_samples.append(chain)

  return z_samples

def m_step_MCMC(z_samples, components):

  n = len(data)
  k = len(components)

  flatz = [z for chain in z_samples for z in chain]

  total = len(flatz)

  eps = 1e-6
  min_weight = 0.05

  for i in range(k):
    count_i = flatz.count(i)
    pi_i = (count_i + eps) / (total)
    components[i]["pi"] =  max(min_weight, pi_i)  # Updates pi / how much each distribution is mixed with how many exposures we got of the the specific distribution for all the data samples / total
                                                 # we give (count_i + e-6) for the case when our samples got us no cases when the data point was associated with pi_i distribution. This would make it so
                                                    # that theres no chance for the distribution to be revived no matter the pdf we get exposed to in the e step.

  new_total = sum(comp["pi"] for comp in components)

  for i in range(k):
    components[i]["pi"] /= new_total # normalizing because of min_weight

  return components

def update_params_pdfs(data, components, z_samples):
  k = len(components)
  n = len(data)

  flat_x = [x for i, x in enumerate(data) for j in range(len(z_samples[i]))]
  flat_z = [z for chain in z_samples for z in chain]

  for i in range(len(components)):
      print(f"Component {i}: {components[i]['distr name']}, count = {flat_z.count(i)}")

  print()

  for i in range(k):

    spec_data  = [x for x, z in zip(flat_x, flat_z) if z == i] # filters data points into what distribution we think the data points are associated with

    if components[i]["distr name"] == "Uniform":
      if spec_data: # Add check for empty list
        components[i]["params"] = (min(spec_data), max(spec_data))
      else:
        pass

    if components[i]["distr name"] == "Exponential":
      if spec_data: # Add check for empty list
        components[i]["params"] = (np.mean(spec_data),)
      else:
        pass

    if components[i]["distr name"] == "Normal":
      if spec_data: # Add check for empty list
        components[i]["params"] = (np.mean(spec_data), np.std(spec_data))
      else:
        pass

    if components[i]["distr name"] == "Bernoulli":
      if spec_data:
        components[i]["params"] = (np.mean(spec_data),)
      else:
        pass

    if components[i]["distr name"] == "Poisson":
      if spec_data:
        components[i]["params"] = (np.mean(spec_data),)
      else:
        pass

  for comp in components:
      name = comp["distr name"]
      params = comp["params"]

      if name == "Normal":
        if len(spec_data) > 5:
          mu, sigma = params
          def f(x, mu=mu, sigma=sigma):
              return (1 / (sigma * math.sqrt(2 * math.pi))) * math.exp(-(x - mu)**2 / (2 * sigma**2))
          comp["pdf"] = f
      elif name == "Poisson":
          lamb = params[0]
          def f(x, lamb=lamb):
              if x >= 0 and float(x).is_integer():
                  return (math.exp(-lamb) * (lamb ** x)) / math.factorial(int(x))
              else:
                  return 0
          comp["pdf"] = f
      elif name == "Exponential":
          theta = params[0]
          def f(x, theta=theta):
              return (1 / theta) * math.exp(-x / theta) if x >= 0 else 0
          comp["pdf"] = f
      elif name == "Uniform":
          a, b = params
          def f(x, a=a, b=b):
              return 1 / (b - a) if a <= x <= b else 0
          comp["pdf"] = f
      elif name == "Bernoulli":
          p = params[0]
          def f(x, p=p):
              return p if x == 1 else (1 - p) if x == 0 else 0
          comp["pdf"] = f
      else:
          raise ValueError(f"Unknown distribution name: {name}")

  return components

def compute_log_likelihood(data, components):
    log_likelihood = 0
    for x in data:
        mixture_prob = sum(comp['pi'] * comp['pdf'](x) for comp in components)
        if mixture_prob > 0:
            log_likelihood += np.log(mixture_prob)
    return log_likelihood


def EM_MCMC(data, num_iters):

  components = []

  # data = [0, 1, 8, 6, 2, 4] # Removed hardcoded data

  num_components = int(input("How many distributions would you like to mix? "))

  components = []
  for i in range(num_components):
    distr = ''
    while distr not in ["Uniform", "Exponential", "Normal", "Poisson", "Bernoulli"]:
      distr = input(f"Choose distribution {i+1}: ")
    pdf_f, param = pick_distribution(distr)
    components.append({"distr name": distr, "pdf": pdf_f, "params": param, "pi": 1 / num_components}) # --> Start by assuming that each data point has equal
                                                                                                          # chance of being associated with one of the distributions.
  ll_list = []
  for i in range(num_iters):
    z_samples = e_step_MCMC(data, components) #
    components = m_step_MCMC(z_samples, components)
    components = update_params_pdfs(data, components, z_samples)

    ll = compute_log_likelihood(data, components)
    ll_list.append(ll)
    if i > 0:
      print(f"Iteration {i+1}: Log-likelihood = {ll}")

  # plot log likelihood changes
  plt.figure(figsize=(10, 6))
  plt.scatter(range(len(ll_list)), ll_list, label='Data')

  coeffs = np.polyfit(range(len(ll_list)), ll_list, deg=3)
  trendline = np.poly1d(coeffs)

  plt.plot(range(len(ll_list)), trendline(range(len(ll_list))), color='blue', label='Trendline')

  plt.xlabel("iteration")
  plt.ylabel("log likelihood")
  plt.legend()
  plt.show()

  print("Final parameters:")

  for i in range(len(components)):
    print(f"Component {i+1}: {components[i]['distr name']}")
    print("Parameters:", *(float(x) for x in components[i]['params']))
    print(f"Weight: {float(components[i]['pi'])}")
    print()
  return

np.random.seed(924)

# Generate data
n = 300
data = []

# 40% Normal(2, 0.5)
data += list(np.random.normal(loc=2, scale=0.5, size=int(0.4 * n)))

# 30% Uniform(0,5)
data += list(np.random.uniform(0,5, size=int(0.3 * n)))

# 30% Exponential(1.5)
data += list(np.random.exponential(scale=1.5, size=int(0.3 * n)))

# Optional: Shuffle the data
random.shuffle(data)


EM_MCMC(data, 100)
# Out:
# How many distributions would you like to mix? 3
# Choose distribution 1: Normal
# Enter the mean guess: 3
# Enter the standard deviation guess: 4
# Choose distribution 2: Uniform
# Initial lower bound guess: 2
# Initial upper bound guess: 5
# Choose distribution 3: Exponential
# Enter the mean guess: 1.2
# Component 0: Normal, count = 6631
# Component 1: Uniform, count = 8561
# Component 2: Exponential, count = 14808
#
# Component 0: Normal, count = 7667
# Component 1: Uniform, count = 7038
# Component 2: Exponential, count = 15295
#
# Iteration 2: Log-likelihood = -466.6643098473204
# Component 0: Normal, count = 9187
# Component 1: Uniform, count = 5976
# Component 2: Exponential, count = 14837
#
# Iteration 3: Log-likelihood = -454.8595423883621
# Component 0: Normal, count = 10749
# Component 1: Uniform, count = 5489
# Component 2: Exponential, count = 13762
#
# Iteration 4: Log-likelihood = -448.77460903777205
# Component 0: Normal, count = 11756
# Component 1: Uniform, count = 5314
# Component 2: Exponential, count = 12930
#
# Iteration 5: Log-likelihood = -446.4700715917274
# Component 0: Normal, count = 12372
# Component 1: Uniform, count = 5329
# Component 2: Exponential, count = 12299
#
# Iteration 6: Log-likelihood = -445.68811290522984
# Component 0: Normal, count = 12803
# Component 1: Uniform, count = 5503
# Component 2: Exponential, count = 11694
#
# Iteration 7: Log-likelihood = -445.1853550193295
# Component 0: Normal, count = 12977
# Component 1: Uniform, count = 5569
# Component 2: Exponential, count = 11454
#
# Iteration 8: Log-likelihood = -445.05867351881295
# Component 0: Normal, count = 13152
# Component 1: Uniform, count = 5705
# Component 2: Exponential, count = 11143
#
# Iteration 9: Log-likelihood = -444.90806766959594
# Component 0: Normal, count = 13177
# Component 1: Uniform, count = 5827
# Component 2: Exponential, count = 10996
#
# Iteration 10: Log-likelihood = -444.85601144181055
# Component 0: Normal, count = 13240
# Component 1: Uniform, count = 5891
# Component 2: Exponential, count = 10869
#
# Iteration 11: Log-likelihood = -444.81514795611525
# Component 0: Normal, count = 13410
# Component 1: Uniform, count = 5955
# Component 2: Exponential, count = 10635
#
# Iteration 12: Log-likelihood = -444.7762629054636
# Component 0: Normal, count = 13270
# Component 1: Uniform, count = 6025
# Component 2: Exponential, count = 10705
#
# Iteration 13: Log-likelihood = -444.8293089243889
# Component 0: Normal, count = 13416
# Component 1: Uniform, count = 6128
# Component 2: Exponential, count = 10456
#
# Iteration 14: Log-likelihood = -444.7881762120035
# Component 0: Normal, count = 13517
# Component 1: Uniform, count = 6121
# Component 2: Exponential, count = 10362
#
# Iteration 15: Log-likelihood = -444.74911179622075
# Component 0: Normal, count = 13544
# Component 1: Uniform, count = 6192
# Component 2: Exponential, count = 10264
#
# Iteration 16: Log-likelihood = -444.75149926919323
# Component 0: Normal, count = 13547
# Component 1: Uniform, count = 6160
# Component 2: Exponential, count = 10293
#
# Iteration 17: Log-likelihood = -444.74999988785993
# Component 0: Normal, count = 13556
# Component 1: Uniform, count = 6166
# Component 2: Exponential, count = 10278
#
# Iteration 18: Log-likelihood = -444.7304822017463
# Component 0: Normal, count = 13645
# Component 1: Uniform, count = 6125
# Component 2: Exponential, count = 10230
#
# Iteration 19: Log-likelihood = -444.72808514587183
# Component 0: Normal, count = 13604
# Component 1: Uniform, count = 6161
# Component 2: Exponential, count = 10235
#
# Iteration 20: Log-likelihood = -444.7338637443619
# Component 0: Normal, count = 13493
# Component 1: Uniform, count = 6214
# Component 2: Exponential, count = 10293
#
# Iteration 21: Log-likelihood = -444.74091309576824
# Component 0: Normal, count = 13492
# Component 1: Uniform, count = 6183
# Component 2: Exponential, count = 10325
#
# Iteration 22: Log-likelihood = -444.73203596883974
# Component 0: Normal, count = 13406
# Component 1: Uniform, count = 6202
# Component 2: Exponential, count = 10392
#
# Iteration 23: Log-likelihood = -444.7541698967644
# Component 0: Normal, count = 13481
# Component 1: Uniform, count = 6195
# Component 2: Exponential, count = 10324
#
# Iteration 24: Log-likelihood = -444.8261104217723
# Component 0: Normal, count = 13563
# Component 1: Uniform, count = 6087
# Component 2: Exponential, count = 10350
#
# Iteration 25: Log-likelihood = -444.8679747093088
# Component 0: Normal, count = 13625
# Component 1: Uniform, count = 6071
# Component 2: Exponential, count = 10304
#
# Iteration 26: Log-likelihood = -444.8143822947416
# Component 0: Normal, count = 13595
# Component 1: Uniform, count = 6054
# Component 2: Exponential, count = 10351
#
# Iteration 27: Log-likelihood = -444.7732001531264
# Component 0: Normal, count = 13651
# Component 1: Uniform, count = 6076
# Component 2: Exponential, count = 10273
#
# Iteration 28: Log-likelihood = -444.75186157496057
# Component 0: Normal, count = 13576
# Component 1: Uniform, count = 6145
# Component 2: Exponential, count = 10279
#
# Iteration 29: Log-likelihood = -444.7798299462714
# Component 0: Normal, count = 13718
# Component 1: Uniform, count = 6173
# Component 2: Exponential, count = 10109
#
# Iteration 30: Log-likelihood = -444.76701140766954
# Component 0: Normal, count = 13661
# Component 1: Uniform, count = 6221
# Component 2: Exponential, count = 10118
#
# Iteration 31: Log-likelihood = -444.7739157450186
# Component 0: Normal, count = 13558
# Component 1: Uniform, count = 6266
# Component 2: Exponential, count = 10176
#
# Iteration 32: Log-likelihood = -444.80244287603125
# Component 0: Normal, count = 13611
# Component 1: Uniform, count = 6236
# Component 2: Exponential, count = 10153
#
# Iteration 33: Log-likelihood = -444.78311270311286
# Component 0: Normal, count = 13676
# Component 1: Uniform, count = 6257
# Component 2: Exponential, count = 10067
#
# Iteration 34: Log-likelihood = -444.7425291375569
# Component 0: Normal, count = 13555
# Component 1: Uniform, count = 6177
# Component 2: Exponential, count = 10268
#
# Iteration 35: Log-likelihood = -444.7376774631512
# Component 0: Normal, count = 13636
# Component 1: Uniform, count = 6075
# Component 2: Exponential, count = 10289
#
# Iteration 36: Log-likelihood = -444.74699722390096
# Component 0: Normal, count = 13549
# Component 1: Uniform, count = 6122
# Component 2: Exponential, count = 10329
#
# Iteration 37: Log-likelihood = -444.73622780347176
# Component 0: Normal, count = 13586
# Component 1: Uniform, count = 6094
# Component 2: Exponential, count = 10320
#
# Iteration 38: Log-likelihood = -444.76319251619753
# Component 0: Normal, count = 13574
# Component 1: Uniform, count = 6114
# Component 2: Exponential, count = 10312
#
# Iteration 39: Log-likelihood = -444.7466063369629
# Component 0: Normal, count = 13596
# Component 1: Uniform, count = 6146
# Component 2: Exponential, count = 10258
#
# Iteration 40: Log-likelihood = -444.7622544077571
# Component 0: Normal, count = 13613
# Component 1: Uniform, count = 6108
# Component 2: Exponential, count = 10279
#
# Iteration 41: Log-likelihood = -444.7527026102893
# Component 0: Normal, count = 13692
# Component 1: Uniform, count = 6083
# Component 2: Exponential, count = 10225
#
# Iteration 42: Log-likelihood = -444.78737175826956
# Component 0: Normal, count = 13784
# Component 1: Uniform, count = 6017
# Component 2: Exponential, count = 10199
#
# Iteration 43: Log-likelihood = -444.822902901345
# Component 0: Normal, count = 13672
# Component 1: Uniform, count = 6045
# Component 2: Exponential, count = 10283
#
# Iteration 44: Log-likelihood = -444.79255257132104
# Component 0: Normal, count = 13635
# Component 1: Uniform, count = 6082
# Component 2: Exponential, count = 10283
#
# Iteration 45: Log-likelihood = -444.78161920169947
# Component 0: Normal, count = 13770
# Component 1: Uniform, count = 6097
# Component 2: Exponential, count = 10133
#
# Iteration 46: Log-likelihood = -444.78012708863514
# Component 0: Normal, count = 13722
# Component 1: Uniform, count = 6115
# Component 2: Exponential, count = 10163
#
# Iteration 47: Log-likelihood = -444.7696379536933
# Component 0: Normal, count = 13617
# Component 1: Uniform, count = 6073
# Component 2: Exponential, count = 10310
#
# Iteration 48: Log-likelihood = -444.78596427692094
# Component 0: Normal, count = 13785
# Component 1: Uniform, count = 6013
# Component 2: Exponential, count = 10202
#
# Iteration 49: Log-likelihood = -444.7909893569588
# Component 0: Normal, count = 13769
# Component 1: Uniform, count = 5988
# Component 2: Exponential, count = 10243
#
# Iteration 50: Log-likelihood = -444.81929942672036
# Component 0: Normal, count = 13929
# Component 1: Uniform, count = 5962
# Component 2: Exponential, count = 10109
#
# Iteration 51: Log-likelihood = -444.7979727914979
# Component 0: Normal, count = 14073
# Component 1: Uniform, count = 5917
# Component 2: Exponential, count = 10010
#
# Iteration 52: Log-likelihood = -444.78663708380157
# Component 0: Normal, count = 13980
# Component 1: Uniform, count = 5945
# Component 2: Exponential, count = 10075
#
# Iteration 53: Log-likelihood = -444.7960863353163
# Component 0: Normal, count = 13966
# Component 1: Uniform, count = 5946
# Component 2: Exponential, count = 10088
#
# Iteration 54: Log-likelihood = -444.83672995715324
# Component 0: Normal, count = 13926
# Component 1: Uniform, count = 5919
# Component 2: Exponential, count = 10155
#
# Iteration 55: Log-likelihood = -444.8502240710336
# Component 0: Normal, count = 13878
# Component 1: Uniform, count = 5923
# Component 2: Exponential, count = 10199
#
# Iteration 56: Log-likelihood = -444.83824696822876
# Component 0: Normal, count = 13900
# Component 1: Uniform, count = 6050
# Component 2: Exponential, count = 10050
#
# Iteration 57: Log-likelihood = -444.83988742682914
# Component 0: Normal, count = 14013
# Component 1: Uniform, count = 6001
# Component 2: Exponential, count = 9986
#
# Iteration 58: Log-likelihood = -444.83639420242736
# Component 0: Normal, count = 13971
# Component 1: Uniform, count = 5984
# Component 2: Exponential, count = 10045
#
# Iteration 59: Log-likelihood = -444.82871765663333
# Component 0: Normal, count = 14149
# Component 1: Uniform, count = 5910
# Component 2: Exponential, count = 9941
#
# Iteration 60: Log-likelihood = -444.82579704743006
# Component 0: Normal, count = 14052
# Component 1: Uniform, count = 6009
# Component 2: Exponential, count = 9939
#
# Iteration 61: Log-likelihood = -444.82536828050513
# Component 0: Normal, count = 14039
# Component 1: Uniform, count = 5997
# Component 2: Exponential, count = 9964
#
# Iteration 62: Log-likelihood = -444.81363010546147
# Component 0: Normal, count = 14015
# Component 1: Uniform, count = 6057
# Component 2: Exponential, count = 9928
#
# Iteration 63: Log-likelihood = -444.81664978378745
# Component 0: Normal, count = 14025
# Component 1: Uniform, count = 6133
# Component 2: Exponential, count = 9842
#
# Iteration 64: Log-likelihood = -444.80605329055146
# Component 0: Normal, count = 13995
# Component 1: Uniform, count = 6203
# Component 2: Exponential, count = 9802
#
# Iteration 65: Log-likelihood = -444.8015079102721
# Component 0: Normal, count = 13902
# Component 1: Uniform, count = 6167
# Component 2: Exponential, count = 9931
#
# Iteration 66: Log-likelihood = -444.7743159003806
# Component 0: Normal, count = 13782
# Component 1: Uniform, count = 6253
# Component 2: Exponential, count = 9965
#
# Iteration 67: Log-likelihood = -444.77711535531637
# Component 0: Normal, count = 13807
# Component 1: Uniform, count = 6296
# Component 2: Exponential, count = 9897
#
# Iteration 68: Log-likelihood = -444.78318243964276
# Component 0: Normal, count = 13894
# Component 1: Uniform, count = 6243
# Component 2: Exponential, count = 9863
#
# Iteration 69: Log-likelihood = -444.8223632645477
# Component 0: Normal, count = 13824
# Component 1: Uniform, count = 6273
# Component 2: Exponential, count = 9903
#
# Iteration 70: Log-likelihood = -444.8000059378645
# Component 0: Normal, count = 13750
# Component 1: Uniform, count = 6216
# Component 2: Exponential, count = 10034
#
# Iteration 71: Log-likelihood = -444.7850679807637
# Component 0: Normal, count = 13708
# Component 1: Uniform, count = 6239
# Component 2: Exponential, count = 10053
#
# Iteration 72: Log-likelihood = -444.7783702393322
# Component 0: Normal, count = 13865
# Component 1: Uniform, count = 6169
# Component 2: Exponential, count = 9966
#
# Iteration 73: Log-likelihood = -444.74980260796
# Component 0: Normal, count = 13833
# Component 1: Uniform, count = 6147
# Component 2: Exponential, count = 10020
#
# Iteration 74: Log-likelihood = -444.76147947299785
# Component 0: Normal, count = 13985
# Component 1: Uniform, count = 6017
# Component 2: Exponential, count = 9998
#
# Iteration 75: Log-likelihood = -444.7792668147017
# Component 0: Normal, count = 13945
# Component 1: Uniform, count = 5978
# Component 2: Exponential, count = 10077
#
# Iteration 76: Log-likelihood = -444.77622187559643
# Component 0: Normal, count = 13792
# Component 1: Uniform, count = 6031
# Component 2: Exponential, count = 10177
#
# Iteration 77: Log-likelihood = -444.78846568006
# Component 0: Normal, count = 13586
# Component 1: Uniform, count = 6087
# Component 2: Exponential, count = 10327
#
# Iteration 78: Log-likelihood = -444.80941988440367
# Component 0: Normal, count = 13781
# Component 1: Uniform, count = 5981
# Component 2: Exponential, count = 10238
#
# Iteration 79: Log-likelihood = -444.7635859938541
# Component 0: Normal, count = 13718
# Component 1: Uniform, count = 6097
# Component 2: Exponential, count = 10185
#
# Iteration 80: Log-likelihood = -444.75418265106464
# Component 0: Normal, count = 13634
# Component 1: Uniform, count = 6100
# Component 2: Exponential, count = 10266
#
# Iteration 81: Log-likelihood = -444.8123469454864
# Component 0: Normal, count = 13478
# Component 1: Uniform, count = 6220
# Component 2: Exponential, count = 10302
#
# Iteration 82: Log-likelihood = -444.75806599092266
# Component 0: Normal, count = 13490
# Component 1: Uniform, count = 6170
# Component 2: Exponential, count = 10340
#
# Iteration 83: Log-likelihood = -444.76800252869003
# Component 0: Normal, count = 13536
# Component 1: Uniform, count = 6110
# Component 2: Exponential, count = 10354
#
# Iteration 84: Log-likelihood = -444.76675878569193
# Component 0: Normal, count = 13543
# Component 1: Uniform, count = 6107
# Component 2: Exponential, count = 10350
#
# Iteration 85: Log-likelihood = -444.77724017286107
# Component 0: Normal, count = 13708
# Component 1: Uniform, count = 6037
# Component 2: Exponential, count = 10255
#
# Iteration 86: Log-likelihood = -444.8647429412929
# Component 0: Normal, count = 13717
# Component 1: Uniform, count = 6032
# Component 2: Exponential, count = 10251
#
# Iteration 87: Log-likelihood = -444.88042219551096
# Component 0: Normal, count = 13763
# Component 1: Uniform, count = 6035
# Component 2: Exponential, count = 10202
#
# Iteration 88: Log-likelihood = -444.83170994539654
# Component 0: Normal, count = 13816
# Component 1: Uniform, count = 6006
# Component 2: Exponential, count = 10178
#
# Iteration 89: Log-likelihood = -444.80954817591186
# Component 0: Normal, count = 13908
# Component 1: Uniform, count = 6016
# Component 2: Exponential, count = 10076
#
# Iteration 90: Log-likelihood = -444.8301670518334
# Component 0: Normal, count = 13864
# Component 1: Uniform, count = 6050
# Component 2: Exponential, count = 10086
#
# Iteration 91: Log-likelihood = -444.8202076997009
# Component 0: Normal, count = 13826
# Component 1: Uniform, count = 6183
# Component 2: Exponential, count = 9991
#
# Iteration 92: Log-likelihood = -444.85542392011433
# Component 0: Normal, count = 13953
# Component 1: Uniform, count = 6210
# Component 2: Exponential, count = 9837
#
# Iteration 93: Log-likelihood = -444.8605305746642
# Component 0: Normal, count = 14023
# Component 1: Uniform, count = 6210
# Component 2: Exponential, count = 9767
#
# Iteration 94: Log-likelihood = -444.84485456331527
# Component 0: Normal, count = 13981
# Component 1: Uniform, count = 6232
# Component 2: Exponential, count = 9787
#
# Iteration 95: Log-likelihood = -444.79726453536324
# Component 0: Normal, count = 13952
# Component 1: Uniform, count = 6200
# Component 2: Exponential, count = 9848
#
# Iteration 96: Log-likelihood = -444.79192625632345
# Component 0: Normal, count = 13799
# Component 1: Uniform, count = 6184
# Component 2: Exponential, count = 10017
#
# Iteration 97: Log-likelihood = -444.7758457275041
# Component 0: Normal, count = 13827
# Component 1: Uniform, count = 6064
# Component 2: Exponential, count = 10109
#
# Iteration 98: Log-likelihood = -444.76110047550856
# Component 0: Normal, count = 13909
# Component 1: Uniform, count = 6117
# Component 2: Exponential, count = 9974
#
# Iteration 99: Log-likelihood = -444.7520047193279
# Component 0: Normal, count = 14054
# Component 1: Uniform, count = 6056
# Component 2: Exponential, count = 9890
#
# Iteration 100: Log-likelihood = -444.77865036946497
# Final parameters:
# Component 1: Normal
# Parameters: 1.8460064463447392 0.5583405533495043
# Weight: 0.46846666665315334
#
# Component 2: Uniform
# Parameters: 2.001249637992631 4.939563309234937
# Weight: 0.20186666667981334
#
# Component 3: Exponential
# Parameters: 1.2533636181134291
# Weight: 0.3296666666670333

# %% [markdown]
# This is a user input based code, where the user may pick the amount of mixes, distribution types, and parameters.
#
# I will focus on two functions implemented here:
#
# - e_step_MCMC: This step iterates between each data point, makes a list of our current weight mix times the pdf at data point value, sums it up to then on make probability weight for our initial z value. It then goes to iterate over the num steps we decided by look at a random z, checking it $\alpha$, and making a random decision to go to that z, and add it to the list.
#
# - m_step_MCMC: This step flattens our list of lists (or changes seperate samples into one big sample). For each component, is counts the amount of sample points we got, and divides by total. Whats important here is the inclusion of the min_weight, which tells us that no matter what no mixed weight will be below 0.05. This can obviously cause problems for higher mixes, but if we didn't have some minimum value here we could possibly get a mixing weight of 0. This would in turn totally close off the distribution being a possibility for the next sample. This is normalized then after.

# %% [markdown]
# The second I did was the normal...

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import math
import functools

#Normal#########################################################################
################################################################################
################################################################################
################################################################################
################################################################################
def pick_distribution(answer):

  if answer == "Uniform":
    while True:
      try:
        a0 = float(input("Initial lower bound guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")
    while True:
      try:
        b0 = float(input("Initial upper bound guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")
    def pdf(x):
      return 1 / (b0 - a0) if a0 <= x <= b0 else 0

    return pdf, (a0, b0)

  if answer == "Exponential":
    while True:
      try:
        theta0 = float(input("Enter the mean guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")

    def pdf(x):
      return (1 / theta0) * math.exp(-x / theta0) if x >= 0 else 0

    return pdf, (theta0,) # Corrected parameter return

  if answer == "Normal":
    while True:
      try:
        mu0 = float(input("Enter the mean guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")
    while True:
      try:
        sigma0 = float(input("Enter the standard deviation guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")
    def pdf(x_val):
      return (1 / (sigma0 * math.sqrt(2 * math.pi))) * math.exp(-(x_val - mu0)**2 / (2 * sigma0**2))
    return pdf, (mu0, sigma0)

  if answer == "Bernoulli":
    while True:
        try:
            p = float(input("Enter probability of success (0 < p < 1): "))
            if 0 < p < 1:
                break
            else:
                print("p must be between 0 and 1.")
        except ValueError:
            print("Invalid input. Please enter a number.")

    def pdf(x):
        return p if x == 1 else (1 - p) if x == 0 else 0

    return pdf, (p,)

  if answer == "Poisson":

    integer_data = [x for x in data if float(x).is_integer()]
    estimated_lambda = np.mean(integer_data) if integer_data else 3.0

    print(f"Suggested lambda (from integer data): {estimated_lambda:.2f}")
    while True:
        try:
            lambda_val = float(input("Enter the Poisson mean (lambda): "))
            if lambda_val > 0:
                break
            else:
                print("lambda must be greater than 0.")
        except ValueError:
            print("Invalid input. Please enter a number.")
    def pdf(x):
      if x >= 0 and float(x).is_integer():
          return (math.exp(-lambda_val) * (lambda_val ** x)) / math.factorial(int(x)) # Corrected condition and factorial input
      else:
          return 0

    return pdf, (lambda_val,)


  # More distributions TBC

#-------------------------------------------------------------------------------

def e_step(data, components):
  responsibilities = []
  for x in data:
    num = [comp["pi"] * comp["pdf"](x) for comp in components]
    tot = sum(num)
    if tot == 0:
      probs = [1 / len(components)] * len(components)
    else:
      probs = [n / tot for n in num]
    responsibilities.append(probs)
  return responsibilities

def m_step(data, responsibilities, components):
    n = len(data)
    k = len(components)

    for i in range(k):
        r_i = [resp[i] for resp in responsibilities]
        total_r = sum(r_i)
        components[i]["pi"] = total_r / n if total_r > 0 else 1e-6

        spec_data = [x * r for x, r in zip(data, r_i)]

        if components[i]["distr name"] == "Uniform":
            # Weighted min/max
            weights = np.array(r_i)
            if np.sum(weights) > 0:
                x_array = np.array(data)
                components[i]["params"] = (np.min(x_array[weights > 0]), np.max(x_array[weights > 0]))
            else:
                pass # Keep previous parameters if no data points assigned to this component

        elif components[i]["distr name"] == "Exponential":
            if total_r > 0:
                theta = sum(spec_data) / total_r
                components[i]["params"] = (theta,)
            else:
                pass # Keep previous parameters if no data points assigned to this component

        elif components[i]["distr name"] == "Normal":
            if total_r > 0:
                mu = sum(spec_data) / total_r
                var = sum(r * ((x - mu)**2) for x, r in zip(data, r_i)) / total_r
                sigma = math.sqrt(var)
                components[i]["params"] = (mu, sigma)
            else:
                pass # Keep previous parameters if no data points assigned to this component

        elif components[i]["distr name"] == "Bernoulli":
            if total_r > 0:
                p = sum(spec_data) / total_r
                components[i]["params"] = (p,)
            else:
                pass # Keep previous parameters if no data points assigned to this component

        elif components[i]["distr name"] == "Poisson":
            if total_r > 0:
                lambda_ = sum(spec_data) / total_r
                components[i]["params"] = (lambda_,)
            else:
                pass # Keep previous parameters if no data points assigned to this component


    update_pdfs(components)
    return components

def update_pdfs(components):
    for comp in components:
        name = comp["distr name"]
        params = comp["params"]

        if name == "Normal":
            mu, sigma = params
            def f(x, mu=mu, sigma=sigma):
                return (1 / (sigma * math.sqrt(2 * math.pi))) * math.exp(-(x - mu)**2 / (2 * sigma**2))
            comp["pdf"] = f

        elif name == "Poisson":
            lamb = params[0]
            def f(x, lamb=lamb):
                if x >= 0 and float(x).is_integer():
                    return (math.exp(-lamb) * (lamb ** x)) / math.factorial(int(x))
                else:
                    return 0
            comp["pdf"] = f

        elif name == "Exponential":
            theta = params[0]
            def f(x, theta=theta):
                return (1 / theta) * math.exp(-x / theta) if x >= 0 else 0
            comp["pdf"] = f

        elif name == "Uniform":
            a, b = params
            def f(x, a=a, b=b):
                return 1 / (b - a) if a <= x <= b else 0
            comp["pdf"] = f

        elif name == "Bernoulli":
            p = params[0]
            def f(x, p=p):
                return p if x == 1 else (1 - p) if x == 0 else 0
            comp["pdf"] = f

        else:
            raise ValueError(f"Unknown distribution name: {name}")

#-------------------------------------------------------------------------------
def update_params_pdfs(data, components, z_samples):
  k = len(components)
  n = len(data)

  flat_x = [x for i, x in enumerate(data) for j in range(len(z_samples[i]))]
  flat_z = [z for chain in z_samples for z in chain]

  for i in range(len(components)):
      print(f"Component {i}: {components[i]['distr name']}, count = {flat_z.count(i)}")

  print()

  for i in range(k):

    spec_data  = [x for x, z in zip(flat_x, flat_z) if z == i] # filters data points into what distribution we think the data points are associated with

    if components[i]["distr name"] == "Uniform":
      if spec_data: # Add check for empty list
        components[i]["params"] = (min(spec_data), max(spec_data))
      else:
        pass

    if components[i]["distr name"] == "Exponential":
      if spec_data: # Add check for empty list
        components[i]["params"] = (np.mean(spec_data),)
      else:
        pass

    if components[i]["distr name"] == "Normal":
      if spec_data: # Add check for empty list
        components[i]["params"] = (np.mean(spec_data), np.std(spec_data))
      else:
        pass

    if components[i]["distr name"] == "Bernoulli":
      if spec_data:
        components[i]["params"] = (np.mean(spec_data),)
      else:
        pass

    if components[i]["distr name"] == "Poisson":
      if spec_data:
        components[i]["params"] = (np.mean(spec_data),)
      else:
        pass

  for comp in components:
      name = comp["distr name"]
      params = comp["params"]

      if name == "Normal":
        if len(spec_data) > 5:
          mu, sigma = params
          def f(x, mu=mu, sigma=sigma):
              return (1 / (sigma * math.sqrt(2 * math.pi))) * math.exp(-(x - mu)**2 / (2 * sigma**2))
          comp["pdf"] = f
      elif name == "Poisson":
          lamb = params[0]
          def f(x, lamb=lamb):
              if x >= 0 and float(x).is_integer():
                  return (math.exp(-lamb) * (lamb ** x)) / math.factorial(int(x))
              else:
                  return 0
          comp["pdf"] = f
      elif name == "Exponential":
          theta = params[0]
          def f(x, theta=theta):
              return (1 / theta) * math.exp(-x / theta) if x >= 0 else 0
          comp["pdf"] = f
      elif name == "Uniform":
          a, b = params
          def f(x, a=a, b=b):
              return 1 / (b - a) if a <= x <= b else 0
          comp["pdf"] = f
      elif name == "Bernoulli":
          p = params[0]
          def f(x, p=p):
              return p if x == 1 else (1 - p) if x == 0 else 0
          comp["pdf"] = f
      else:
          raise ValueError(f"Unknown distribution name: {name}")

  return components

def compute_log_likelihood(data, components):
    log_likelihood = 0
    for x in data:
        mixture_prob = sum(comp['pi'] * comp['pdf'](x) for comp in components)
        if mixture_prob > 0:
            log_likelihood += np.log(mixture_prob)
    return log_likelihood


def EM_MCMC(data, num_iters):

  components = []

  # data = [0, 1, 8, 6, 2, 4] # Removed hardcoded data

  num_components = int(input("How many distributions would you like to mix? "))

  components = []
  for i in range(num_components):
    distr = ''
    while distr not in ["Uniform", "Exponential", "Normal", "Poisson", "Bernoulli"]:
      distr = input(f"Choose distribution {i+1}: ")
    pdf_f, param = pick_distribution(distr)
    components.append({"distr name": distr, "pdf": pdf_f, "params": param, "pi": 1 / num_components}) # --> Start by assuming that each data point has equal
                                                                                                          # chance of being associated with one of the distributions.
  ll_list = []
  for i in range(num_iters):
    z_samples = e_step_MCMC(data, components) #
    components = m_step_MCMC(z_samples, components)
    components = update_params_pdfs(data, components, z_samples)

    ll = compute_log_likelihood(data, components)
    ll_list.append(ll)
    if i > 0:
      print(f"Iteration {i+1}: Log-likelihood = {ll}")

  # plot log likelihood changes
  plt.figure(figsize=(10, 6))
  plt.scatter(range(len(ll_list)), ll_list, label='Data')

  coeffs = np.polyfit(range(len(ll_list)), ll_list, deg=3)
  trendline = np.poly1d(coeffs)

  plt.plot(range(len(ll_list)), trendline(range(len(ll_list))), color='blue', label='Trendline')

  plt.xlabel("iteration")
  plt.ylabel("log likelihood")
  plt.legend()
  plt.show()

  print("Final parameters:")

  for i in range(len(components)):
    print(f"Component {i+1}: {components[i]['distr name']}")
    print("Parameters:", *(float(x) for x in components[i]['params']))
    print(f"Weight: {float(components[i]['pi'])}")
    print()
  return

np.random.seed(924)

# Generate data
n = 300
data = []

# 40% Normal(2, 0.5)
data += list(np.random.normal(loc=2, scale=0.5, size=int(0.4 * n)))

# 30% Uniform(0,5)
data += list(np.random.uniform(0,5, size=int(0.3 * n)))

# 30% Exponential(1.5)
data += list(np.random.exponential(scale=1.5, size=int(0.3 * n)))

# Optional: Shuffle the data
random.shuffle(data)


EM_MCMC(data, 100)
# Out:
# How many distributions would you like to mix? 3
# Choose distribution 1: Normal
# Enter the mean guess: 3
# Enter the standard deviation guess: 4
# Choose distribution 2: Uniform
# Initial lower bound guess: 2
# Initial upper bound guess: 5
# Choose distribution 3: Exponential
# Enter the mean guess: 1.2
# Component 0: Normal, count = 6703
# Component 1: Uniform, count = 8377
# Component 2: Exponential, count = 14920
#
# Component 0: Normal, count = 7896
# Component 1: Uniform, count = 6761
# Component 2: Exponential, count = 15343
#
# Iteration 2: Log-likelihood = -465.1294764922388
# Component 0: Normal, count = 9495
# Component 1: Uniform, count = 5831
# Component 2: Exponential, count = 14674
#
# Iteration 3: Log-likelihood = -454.27398275732895
# Component 0: Normal, count = 11001
# Component 1: Uniform, count = 5402
# Component 2: Exponential, count = 13597
#
# Iteration 4: Log-likelihood = -448.71673962966156
# Component 0: Normal, count = 11946
# Component 1: Uniform, count = 5215
# Component 2: Exponential, count = 12839
#
# Iteration 5: Log-likelihood = -446.5203508759089
# Component 0: Normal, count = 12518
# Component 1: Uniform, count = 5276
# Component 2: Exponential, count = 12206
#
# Iteration 6: Log-likelihood = -445.69935414028544
# Component 0: Normal, count = 12866
# Component 1: Uniform, count = 5391
# Component 2: Exponential, count = 11743
#
# Iteration 7: Log-likelihood = -445.27055166742423
# Component 0: Normal, count = 13046
# Component 1: Uniform, count = 5526
# Component 2: Exponential, count = 11428
#
# Iteration 8: Log-likelihood = -445.05870837509127
# Component 0: Normal, count = 13260
# Component 1: Uniform, count = 5654
# Component 2: Exponential, count = 11086
#
# Iteration 9: Log-likelihood = -444.91235960629007
# Component 0: Normal, count = 13275
# Component 1: Uniform, count = 5809
# Component 2: Exponential, count = 10916
#
# Iteration 10: Log-likelihood = -444.85992159535897
# Component 0: Normal, count = 13479
# Component 1: Uniform, count = 5884
# Component 2: Exponential, count = 10637
#
# Iteration 11: Log-likelihood = -444.7931850227622
# Component 0: Normal, count = 13578
# Component 1: Uniform, count = 5930
# Component 2: Exponential, count = 10492
#
# Iteration 12: Log-likelihood = -444.8224454793522
# Component 0: Normal, count = 13507
# Component 1: Uniform, count = 5892
# Component 2: Exponential, count = 10601
#
# Iteration 13: Log-likelihood = -444.86237998646476
# Component 0: Normal, count = 13680
# Component 1: Uniform, count = 5942
# Component 2: Exponential, count = 10378
#
# Iteration 14: Log-likelihood = -444.7982056320134
# Component 0: Normal, count = 13568
# Component 1: Uniform, count = 6053
# Component 2: Exponential, count = 10379
#
# Iteration 15: Log-likelihood = -444.7864416258765
# Component 0: Normal, count = 13635
# Component 1: Uniform, count = 6104
# Component 2: Exponential, count = 10261
#
# Iteration 16: Log-likelihood = -444.7650972930377
# Component 0: Normal, count = 13688
# Component 1: Uniform, count = 6148
# Component 2: Exponential, count = 10164
#
# Iteration 17: Log-likelihood = -444.7976270660677
# Component 0: Normal, count = 13725
# Component 1: Uniform, count = 6132
# Component 2: Exponential, count = 10143
#
# Iteration 18: Log-likelihood = -444.80048610460994
# Component 0: Normal, count = 13790
# Component 1: Uniform, count = 6001
# Component 2: Exponential, count = 10209
#
# Iteration 19: Log-likelihood = -444.8316305236421
# Component 0: Normal, count = 13780
# Component 1: Uniform, count = 5959
# Component 2: Exponential, count = 10261
#
# Iteration 20: Log-likelihood = -444.8303382395652
# Component 0: Normal, count = 13744
# Component 1: Uniform, count = 6014
# Component 2: Exponential, count = 10242
#
# Iteration 21: Log-likelihood = -444.77023804646973
# Component 0: Normal, count = 13755
# Component 1: Uniform, count = 6103
# Component 2: Exponential, count = 10142
#
# Iteration 22: Log-likelihood = -444.7904278246655
# Component 0: Normal, count = 13727
# Component 1: Uniform, count = 6098
# Component 2: Exponential, count = 10175
#
# Iteration 23: Log-likelihood = -444.8635332699399
# Component 0: Normal, count = 13772
# Component 1: Uniform, count = 6132
# Component 2: Exponential, count = 10096
#
# Iteration 24: Log-likelihood = -444.865849227723
# Component 0: Normal, count = 13820
# Component 1: Uniform, count = 6041
# Component 2: Exponential, count = 10139
#
# Iteration 25: Log-likelihood = -444.8290692022247
# Component 0: Normal, count = 13722
# Component 1: Uniform, count = 6028
# Component 2: Exponential, count = 10250
#
# Iteration 26: Log-likelihood = -444.8827928329304
# Component 0: Normal, count = 13637
# Component 1: Uniform, count = 6121
# Component 2: Exponential, count = 10242
#
# Iteration 27: Log-likelihood = -444.8359464033538
# Component 0: Normal, count = 13604
# Component 1: Uniform, count = 6058
# Component 2: Exponential, count = 10338
#
# Iteration 28: Log-likelihood = -444.7875631177801
# Component 0: Normal, count = 13556
# Component 1: Uniform, count = 6087
# Component 2: Exponential, count = 10357
#
# Iteration 29: Log-likelihood = -444.82325953395133
# Component 0: Normal, count = 13730
# Component 1: Uniform, count = 6068
# Component 2: Exponential, count = 10202
#
# Iteration 30: Log-likelihood = -444.8134564481451
# Component 0: Normal, count = 13786
# Component 1: Uniform, count = 5983
# Component 2: Exponential, count = 10231
#
# Iteration 31: Log-likelihood = -444.78183520919356
# Component 0: Normal, count = 13776
# Component 1: Uniform, count = 6077
# Component 2: Exponential, count = 10147
#
# Iteration 32: Log-likelihood = -444.7909436115354
# Component 0: Normal, count = 13821
# Component 1: Uniform, count = 6118
# Component 2: Exponential, count = 10061
#
# Iteration 33: Log-likelihood = -444.7834058189651
# Component 0: Normal, count = 13871
# Component 1: Uniform, count = 6155
# Component 2: Exponential, count = 9974
#
# Iteration 34: Log-likelihood = -444.77729146518084
# Component 0: Normal, count = 13766
# Component 1: Uniform, count = 6207
# Component 2: Exponential, count = 10027
#
# Iteration 35: Log-likelihood = -444.7612567083254
# Component 0: Normal, count = 13795
# Component 1: Uniform, count = 6099
# Component 2: Exponential, count = 10106
#
# Iteration 36: Log-likelihood = -444.78936575746764
# Component 0: Normal, count = 13633
# Component 1: Uniform, count = 6111
# Component 2: Exponential, count = 10256
#
# Iteration 37: Log-likelihood = -444.8259999749689
# Component 0: Normal, count = 13683
# Component 1: Uniform, count = 5945
# Component 2: Exponential, count = 10372
#
# Iteration 38: Log-likelihood = -444.8284621400643
# Component 0: Normal, count = 13593
# Component 1: Uniform, count = 6056
# Component 2: Exponential, count = 10351
#
# Iteration 39: Log-likelihood = -444.8186786556163
# Component 0: Normal, count = 13690
# Component 1: Uniform, count = 6078
# Component 2: Exponential, count = 10232
#
# Iteration 40: Log-likelihood = -444.80203505522314
# Component 0: Normal, count = 13755
# Component 1: Uniform, count = 6076
# Component 2: Exponential, count = 10169
#
# Iteration 41: Log-likelihood = -444.78411229688896
# Component 0: Normal, count = 13780
# Component 1: Uniform, count = 6073
# Component 2: Exponential, count = 10147
#
# Iteration 42: Log-likelihood = -444.7495158494955
# Component 0: Normal, count = 14022
# Component 1: Uniform, count = 6003
# Component 2: Exponential, count = 9975
#
# Iteration 43: Log-likelihood = -444.76468622734154
# Component 0: Normal, count = 13816
# Component 1: Uniform, count = 6133
# Component 2: Exponential, count = 10051
#
# Iteration 44: Log-likelihood = -444.75393771464695
# Component 0: Normal, count = 13671
# Component 1: Uniform, count = 6155
# Component 2: Exponential, count = 10174
#
# Iteration 45: Log-likelihood = -444.77736533151136
# Component 0: Normal, count = 13719
# Component 1: Uniform, count = 6080
# Component 2: Exponential, count = 10201
#
# Iteration 46: Log-likelihood = -444.77233558441526
# Component 0: Normal, count = 13680
# Component 1: Uniform, count = 6215
# Component 2: Exponential, count = 10105
#
# Iteration 47: Log-likelihood = -444.7884018449395
# Component 0: Normal, count = 13600
# Component 1: Uniform, count = 6163
# Component 2: Exponential, count = 10237
#
# Iteration 48: Log-likelihood = -444.80426196110835
# Component 0: Normal, count = 13667
# Component 1: Uniform, count = 6189
# Component 2: Exponential, count = 10144
#
# Iteration 49: Log-likelihood = -444.78882666096627
# Component 0: Normal, count = 13599
# Component 1: Uniform, count = 6156
# Component 2: Exponential, count = 10245
#
# Iteration 50: Log-likelihood = -444.7819567658034
# Component 0: Normal, count = 13718
# Component 1: Uniform, count = 6112
# Component 2: Exponential, count = 10170
#
# Iteration 51: Log-likelihood = -444.79136096821514
# Component 0: Normal, count = 13797
# Component 1: Uniform, count = 6067
# Component 2: Exponential, count = 10136
#
# Iteration 52: Log-likelihood = -444.796028457221
# Component 0: Normal, count = 13796
# Component 1: Uniform, count = 6085
# Component 2: Exponential, count = 10119
#
# Iteration 53: Log-likelihood = -444.7871245397137
# Component 0: Normal, count = 13792
# Component 1: Uniform, count = 6009
# Component 2: Exponential, count = 10199
#
# Iteration 54: Log-likelihood = -444.7769521282473
# Component 0: Normal, count = 13883
# Component 1: Uniform, count = 5909
# Component 2: Exponential, count = 10208
#
# Iteration 55: Log-likelihood = -444.8032001140334
# Component 0: Normal, count = 13880
# Component 1: Uniform, count = 5933
# Component 2: Exponential, count = 10187
#
# Iteration 56: Log-likelihood = -444.82547096254166
# Component 0: Normal, count = 13876
# Component 1: Uniform, count = 5940
# Component 2: Exponential, count = 10184
#
# Iteration 57: Log-likelihood = -444.80252480076126
# Component 0: Normal, count = 13910
# Component 1: Uniform, count = 5989
# Component 2: Exponential, count = 10101
#
# Iteration 58: Log-likelihood = -444.7751741937024
# Component 0: Normal, count = 13814
# Component 1: Uniform, count = 5967
# Component 2: Exponential, count = 10219
#
# Iteration 59: Log-likelihood = -444.77919852456745
# Component 0: Normal, count = 13871
# Component 1: Uniform, count = 5841
# Component 2: Exponential, count = 10288
#
# Iteration 60: Log-likelihood = -444.80517194203316
# Component 0: Normal, count = 13789
# Component 1: Uniform, count = 6013
# Component 2: Exponential, count = 10198
#
# Iteration 61: Log-likelihood = -444.7932463674718
# Component 0: Normal, count = 13916
# Component 1: Uniform, count = 5926
# Component 2: Exponential, count = 10158
#
# Iteration 62: Log-likelihood = -444.8055491759235
# Component 0: Normal, count = 14011
# Component 1: Uniform, count = 6004
# Component 2: Exponential, count = 9985
#
# Iteration 63: Log-likelihood = -444.8528773758522
# Component 0: Normal, count = 14032
# Component 1: Uniform, count = 6011
# Component 2: Exponential, count = 9957
#
# Iteration 64: Log-likelihood = -444.8167552308874
# Component 0: Normal, count = 13863
# Component 1: Uniform, count = 6076
# Component 2: Exponential, count = 10061
#
# Iteration 65: Log-likelihood = -444.78816814887176
# Component 0: Normal, count = 13835
# Component 1: Uniform, count = 6085
# Component 2: Exponential, count = 10080
#
# Iteration 66: Log-likelihood = -444.77573602714114
# Component 0: Normal, count = 13859
# Component 1: Uniform, count = 6155
# Component 2: Exponential, count = 9986
#
# Iteration 67: Log-likelihood = -444.81055708912595
# Component 0: Normal, count = 13918
# Component 1: Uniform, count = 6103
# Component 2: Exponential, count = 9979
#
# Iteration 68: Log-likelihood = -444.7808258858407
# Component 0: Normal, count = 13980
# Component 1: Uniform, count = 6095
# Component 2: Exponential, count = 9925
#
# Iteration 69: Log-likelihood = -444.8093110208268
# Component 0: Normal, count = 14018
# Component 1: Uniform, count = 5970
# Component 2: Exponential, count = 10012
#
# Iteration 70: Log-likelihood = -444.8249426847768
# Component 0: Normal, count = 13918
# Component 1: Uniform, count = 6008
# Component 2: Exponential, count = 10074
#
# Iteration 71: Log-likelihood = -444.83254204165763
# Component 0: Normal, count = 13846
# Component 1: Uniform, count = 6082
# Component 2: Exponential, count = 10072
#
# Iteration 72: Log-likelihood = -444.8140705719973
# Component 0: Normal, count = 13784
# Component 1: Uniform, count = 6173
# Component 2: Exponential, count = 10043
#
# Iteration 73: Log-likelihood = -444.7945599451956
# Component 0: Normal, count = 13797
# Component 1: Uniform, count = 6115
# Component 2: Exponential, count = 10088
#
# Iteration 74: Log-likelihood = -444.81975783256496
# Component 0: Normal, count = 13879
# Component 1: Uniform, count = 6074
# Component 2: Exponential, count = 10047
#
# Iteration 75: Log-likelihood = -444.79587506848986
# Component 0: Normal, count = 13869
# Component 1: Uniform, count = 6131
# Component 2: Exponential, count = 10000
#
# Iteration 76: Log-likelihood = -444.79370711419256
# Component 0: Normal, count = 13893
# Component 1: Uniform, count = 6096
# Component 2: Exponential, count = 10011
#
# Iteration 77: Log-likelihood = -444.7744870834353
# Component 0: Normal, count = 13927
# Component 1: Uniform, count = 6005
# Component 2: Exponential, count = 10068
#
# Iteration 78: Log-likelihood = -444.80383210059045
# Component 0: Normal, count = 13925
# Component 1: Uniform, count = 5973
# Component 2: Exponential, count = 10102
#
# Iteration 79: Log-likelihood = -444.81562443280495
# Component 0: Normal, count = 13927
# Component 1: Uniform, count = 6067
# Component 2: Exponential, count = 10006
#
# Iteration 80: Log-likelihood = -444.82893903050143
# Component 0: Normal, count = 13828
# Component 1: Uniform, count = 6086
# Component 2: Exponential, count = 10086
#
# Iteration 81: Log-likelihood = -444.76474559098784
# Component 0: Normal, count = 13624
# Component 1: Uniform, count = 6074
# Component 2: Exponential, count = 10302
#
# Iteration 82: Log-likelihood = -444.77628422944247
# Component 0: Normal, count = 13591
# Component 1: Uniform, count = 6035
# Component 2: Exponential, count = 10374
#
# Iteration 83: Log-likelihood = -444.78372983465493
# Component 0: Normal, count = 13592
# Component 1: Uniform, count = 6088
# Component 2: Exponential, count = 10320
#
# Iteration 84: Log-likelihood = -444.7839766401834
# Component 0: Normal, count = 13720
# Component 1: Uniform, count = 6036
# Component 2: Exponential, count = 10244
#
# Iteration 85: Log-likelihood = -444.7968397739173
# Component 0: Normal, count = 13754
# Component 1: Uniform, count = 6019
# Component 2: Exponential, count = 10227
#
# Iteration 86: Log-likelihood = -444.80775026171966
# Component 0: Normal, count = 13703
# Component 1: Uniform, count = 6016
# Component 2: Exponential, count = 10281
#
# Iteration 87: Log-likelihood = -444.80415947360177
# Component 0: Normal, count = 13716
# Component 1: Uniform, count = 6024
# Component 2: Exponential, count = 10260
#
# Iteration 88: Log-likelihood = -444.8277506367629
# Component 0: Normal, count = 13669
# Component 1: Uniform, count = 6072
# Component 2: Exponential, count = 10259
#
# Iteration 89: Log-likelihood = -444.80440958982246
# Component 0: Normal, count = 13789
# Component 1: Uniform, count = 5998
# Component 2: Exponential, count = 10213
#
# Iteration 90: Log-likelihood = -444.76850012005264
# Component 0: Normal, count = 13696
# Component 1: Uniform, count = 6028
# Component 2: Exponential, count = 10276
#
# Iteration 91: Log-likelihood = -444.7580642149073
# Component 0: Normal, count = 13683
# Component 1: Uniform, count = 6057
# Component 2: Exponential, count = 10260
#
# Iteration 92: Log-likelihood = -444.7702226441744
# Component 0: Normal, count = 13700
# Component 1: Uniform, count = 5987
# Component 2: Exponential, count = 10313
#
# Iteration 93: Log-likelihood = -444.7948600510882
# Component 0: Normal, count = 13694
# Component 1: Uniform, count = 6023
# Component 2: Exponential, count = 10283
#
# Iteration 94: Log-likelihood = -444.7814829905822
# Component 0: Normal, count = 13722
# Component 1: Uniform, count = 6071
# Component 2: Exponential, count = 10207
#
# Iteration 95: Log-likelihood = -444.77735949121865
# Component 0: Normal, count = 13809
# Component 1: Uniform, count = 6020
# Component 2: Exponential, count = 10171
#
# Iteration 96: Log-likelihood = -444.7517050731858
# Component 0: Normal, count = 13786
# Component 1: Uniform, count = 5991
# Component 2: Exponential, count = 10223
#
# Iteration 97: Log-likelihood = -444.75445575003977
# Component 0: Normal, count = 13771
# Component 1: Uniform, count = 6022
# Component 2: Exponential, count = 10207
#
# Iteration 98: Log-likelihood = -444.7794301620609
# Component 0: Normal, count = 13965
# Component 1: Uniform, count = 6015
# Component 2: Exponential, count = 10020
#
# Iteration 99: Log-likelihood = -444.7785021597151
# Component 0: Normal, count = 13964
# Component 1: Uniform, count = 6041
# Component 2: Exponential, count = 9995
#
# Iteration 100: Log-likelihood = -444.7976364106383
# Final parameters:
# Component 1: Normal
# Parameters: 1.8423191947752293 0.5628494357388811
# Weight: 0.4654666666534534
#
# Component 2: Uniform
# Parameters: 2.001249637992631 4.939563309234937
# Weight: 0.20136666667986333
#
# Component 3: Exponential
# Parameters: 1.2616382356757725
# Weight: 0.3331666666666833

# %% [markdown]
# This code goes off of how the Normal EM is a simple plug and chug method (which also makes it easier on the computer).
#
# I will analyze two functions again:
#
# - e_step: This creates us a list of responsibilities, where each row corresponds to a data point and each column is a distribution.
#
# - m_step: Updates by using the forumla which is the average of responsibilities for all data points. Also updates the parameters makes a utilizes the update_pdfs function which the MCMC EM didn't do.

# %% [markdown]
# After implementing, we now analyze certain data set that we already know the mixes, distributions, and parameters to. This dataset is is 40% normal, 30%  uniform and 30% Exponential. This gave us
#
#
#
# Normal EM:
#
# Final parameters:
# --Component 1: Normal
# --Parameters: 1.8423191947752293 0.5628494357388811
# --Weight: 0.4654666666534534
#
# --Component 2: Uniform
# --Parameters: 2.001249637992631 4.939563309234937
# --Weight: 0.20136666667986333
#
# --Component 3: Exponential
# --Parameters: 1.2616382356757725
# --Weight: 0.3331666666666833
#
# EMMC:
#
# Final parameters:
# --Component 1: Normal
# --Parameters: 1.8460064463447392 0.5583405533495043
# --Weight: 0.46846666665315334
#
# --Component 2: Uniform
# --Parameters: 2.001249637992631 4.939563309234937
# --Weight: 0.20186666667981334
#
# --Component 3: Exponential
# --Parameters: 1.2533636181134291
# --Weight: 0.3296666666670333

# %% [markdown]
# These values seem to be very closely related, showing that these 2 strategies are almost equivalent
#
# I tested with a mix of Continuous and Discrete distributions as well, and a common theme of it was that the continuous distributions dominated. I think this is possibly due to the fact that continuous distributions can take on values that discrete can, but the inverse is not true.

# %% [markdown]
# To further my investigation, I created a mixing function which aloowed to create random mixes of different distributions. This code allowed to no user input and purely off computer randomness.

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import math
#---------------- Distribution Picker ----------------#
def pick_distribution(answer):
    """
    Automatically assigns parameters and returns (pdf, param_tuple)
    based on the chosen distribution name.
    """

    if answer == "Uniform":
        a0 = random.randint(0, 5)
        b0 = random.randint(a0 + 1, a0 + 8)  # ensure b > a
        def pdf(x): return 1 / (b0 - a0) if a0 <= x <= b0 else 0
        return pdf, (a0, b0)

    if answer == "Exponential":
        theta0 = random.uniform(0.5, 5.0)
        def pdf(x): return (1 / theta0) * math.exp(-x / theta0) if x >= 0 else 0
        return pdf, (theta0,)

    if answer == "Normal":
        mu0 = random.uniform(-5, 5)
        sigma0 = random.uniform(0.5, 3.0)
        def pdf(x): return (1 / (sigma0 * math.sqrt(2 * math.pi))) * math.exp(-(x - mu0)**2 / (2 * sigma0**2))
        return pdf, (mu0, sigma0)

    if answer == "Poisson":
        lambda_val = random.uniform(1, 8)
        def pdf(x):
            if x >= 0 and float(x).is_integer():
                x_int = int(x)
                log_pdf = -lambda_val + x_int * math.log(lambda_val) - math.lgamma(x_int + 1)
                return math.exp(log_pdf)
            return 0
        return pdf, (lambda_val,)

    if answer == "Bernoulli":
        p = random.uniform(0.1, 0.9)
        def pdf(x): return p if x == 1 else (1 - p) if x == 0 else 0
        return pdf, (p,)

    raise ValueError(f"Unsupported distribution name: {answer}")

#########################################EM Normal###############################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################

#---------------- PDF Updater ----------------#
def update_pdfs(components):
    """
    After parameter updates, refresh each component's PDF.
    """
    for comp in components:
        name = comp["distr name"]
        params = comp["params"]

        if name == "Normal":
            mu, sigma = params
            comp["pdf"] = lambda x, mu=mu, sigma=sigma: (1 / (sigma * math.sqrt(2 * math.pi))) * math.exp(-(x - mu)**2 / (2 * sigma**2))

        elif name == "Poisson":
            lamb = params[0]
            comp["pdf"] = lambda x, lamb=lamb: math.exp(-lamb + x * math.log(lamb) - math.lgamma(x + 1)) if x >= 0 and float(x).is_integer() else 0

        elif name == "Exponential":
            theta = params[0]
            comp["pdf"] = lambda x, theta=theta: (1 / theta) * math.exp(-x / theta) if x >= 0 else 0

        elif name == "Uniform":
            a, b = params
            comp["pdf"] = lambda x, a=a, b=b: 1 / (b - a) if a <= x <= b else 0

        elif name == "Bernoulli":
            p = params[0]
            comp["pdf"] = lambda x, p=p: p if x == 1 else (1 - p) if x == 0 else 0
        else:
            raise ValueError(f"Unknown distribution name: {name}")

#---------------- E-step ----------------#
def e_step(data, components):
    """
    Estimate responsibilities: P(z_i = j | x_i, θ)
    """
    responsibilities = []
    for x in data:
        weighted_probs = [comp["pi"] * comp["pdf"](x) for comp in components]
        total = sum(weighted_probs)
        probs = [wp / total for wp in weighted_probs] if total > 0 else [1 / len(components)] * len(components)
        responsibilities.append(probs)
    return responsibilities

#---------------- M-step ----------------#
def m_step(data, responsibilities, components):
    """
    Update weights and distribution parameters based on responsibilities.
    """
    n = len(data)
    k = len(components)

    for i in range(k):
        r_i = [resp[i] for resp in responsibilities]
        total_r = sum(r_i)
        components[i]["pi"] = total_r / n if total_r > 0 else 1e-6

        weighted_data = [x * r for x, r in zip(data, r_i)]

        name = components[i]["distr name"]

        if name == "Uniform":
            if np.sum(r_i) > 0:
                x_array = np.array(data)
                components[i]["params"] = (np.min(x_array), np.max(x_array))

        elif name == "Exponential" and total_r > 0:
            theta = sum(weighted_data) / total_r
            components[i]["params"] = (theta,)

        elif name == "Normal" and total_r > 0:
            mu = sum(weighted_data) / total_r
            var = sum(r * ((x - mu)**2) for x, r in zip(data, r_i)) / total_r
            sigma = math.sqrt(var)
            components[i]["params"] = (mu, sigma)

        elif name == "Bernoulli" and total_r > 0:
            p = sum(weighted_data) / total_r
            components[i]["params"] = (p,)

        elif name == "Poisson" and total_r > 0:
            lambda_ = sum(weighted_data) / total_r
            components[i]["params"] = (lambda_,)
    update_pdfs(components)
    return components
#########################################EM MC###############################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################

#---------------- E-Step (MCMC) ----------------#
def e_step_MCMC(data, components, steps=100):
    z_samples = []
    k = len(components)
    for x in data:
        weights = [comp["pi"] * comp["pdf"](x) for comp in components]
        total = sum(weights)
        weights = [w / total for w in weights] if total > 0 else [1 / k] * k
        z = np.random.choice(range(k), p=weights)
        chain = []
        for _ in range(steps):
            if k > 1:
                z_new = np.random.choice([j for j in range(k) if j != z])
                if components[z_new]["distr name"] in {"Poisson", "Bernoulli"} and not float(x).is_integer():
                    chain.append(z)
                    continue
                num = components[z_new]["pi"] * components[z_new]["pdf"](x)
                den = components[z]["pi"] * components[z]["pdf"](x)
                alpha = min(1, num / den if den > 0 else 1)
                if np.random.rand() < alpha:
                    z = z_new
            chain.append(z)
        z_samples.append(chain)
    return z_samples


#---------------- M-Step ----------------#
def m_step_MCMC(z_samples, components):
    flatz = [z for chain in z_samples for z in chain]
    total = len(flatz)
    eps = 1e-6
    min_weight = 0.05
    for i in range(len(components)):
        count_i = flatz.count(i)
        pi_i = (count_i + eps) / total
        components[i]["pi"] = max(min_weight, pi_i)
    total_pi = sum(comp["pi"] for comp in components)
    for comp in components:
        comp["pi"] /= total_pi
    return components


#---------------- Update Parameters ----------------#
def update_params_pdfs(data, components, z_samples):
    flat_x = [x for i, x in enumerate(data) for _ in z_samples[i]]
    flat_z = [z for chain in z_samples for z in chain]
    for i, comp in enumerate(components):
        spec_data = [x for x, z in zip(flat_x, flat_z) if z == i]
        if not spec_data:
            continue
        name = comp["distr name"]
        if name == "Uniform":
            comp["params"] = (min(spec_data), max(spec_data))
        elif name == "Exponential":
            comp["params"] = (np.mean(spec_data),)
        elif name == "Normal":
            comp["params"] = (np.mean(spec_data), np.std(spec_data))
        elif name == "Bernoulli":
            comp["params"] = (np.mean(spec_data),)
        elif name == "Poisson":
            comp["params"] = (np.mean(spec_data),)

        # Update pdfs
        params = comp["params"]
        if name == "Normal":
            mu, sigma = params
            comp["pdf"] = lambda x, mu=mu, sigma=sigma: (1 / (sigma * math.sqrt(2 * math.pi))) * math.exp(-(x - mu)**2 / (2 * sigma**2))
        elif name == "Poisson":
            lamb = params[0]
            comp["pdf"] = lambda x, lamb=lamb: math.exp(-lamb + x * math.log(lamb) - math.lgamma(x + 1)) if x >= 0 and float(x).is_integer() else 0
        elif name == "Exponential":
            theta = params[0]
            comp["pdf"] = lambda x, theta=theta: (1 / theta) * math.exp(-x / theta) if x >= 0 else 0
        elif name == "Uniform":
            a, b = params
            comp["pdf"] = lambda x, a=a, b=b: 1 / (b - a) if a <= x <= b else 0
        elif name == "Bernoulli":
            p = params[0]
            comp["pdf"] = lambda x, p=p: p if x == 1 else (1 - p) if x == 0 else 0
    return components

#---------------- EM-MCMC Main ----------------#
def EM_MCMC(data, true_comps, iter = 25):

    complen = len(true_comps)
    components = []
    for i in range(complen):
      distr = true_comps[i]["distr name"]
      pdf_f, param = pick_distribution(distr)
      components.append({
          "distr name": distr,
          "pdf": pdf_f,
          "params": param,
          "pi": 1/complen # we assume dont know the exact mix of the data
      })

    for i in range(iter):
        z_samples = e_step_MCMC(data, components)
        components = m_step_MCMC(z_samples, components)
        components = update_params_pdfs(data, components, z_samples)

    return [components[i]['pi'] for i in range(complen)]

#---------------- EM Main ----------------#
def EM(data, true_comps, iter = 25):

    num_components = len(true_comps)
    components = []
    for i in range(num_components):
        distr = true_comps[i]["distr name"]
        pdf_f, param = pick_distribution(distr)
        components.append({
            "distr name": distr,
            "pdf": pdf_f,
            "params": param,
            "pi": 1 / num_components
        })

    for i in range(iter):
        responsibilities = e_step(data, components)
        components = m_step(data, responsibilities, components)

    return [components[i]['pi'] for i in range(num_components)]



import random as rd


def give_data_with_mixes_distribs_continuous():

  num_mixes = rd.randint(2, 8)

  distributions = ["Uniform", "Exponential", "Normal"]
  components = []

  true_components = []
  sum = 0
  for i in range(num_mixes):
        distr = rd.choice(distributions)
        pdf_f, param = pick_distribution(distr)
        pi_i = rd.uniform(0, 1 - sum)
        sum += pi_i
        true_components.append({
            "distr name": distr,
            "pdf": pdf_f,
            "params": param,
            "pi": pi_i
        })
  # create data
  data = []
  n = rd.randint(5, 1000)
  for comp in true_components:
    if comp["distr name"] == "Uniform":
      data += list(np.random.uniform(comp["params"][0], comp["params"][1], size=int(comp["pi"] * n)))
    if comp["distr name"] == "Exponential":
      data += list(np.random.exponential(comp["params"][0], size=int(comp["pi"] * n)))
    if comp["distr name"] == "Normal":
      data += list(np.random.normal(comp["params"][0], comp["params"][1], size=int(comp["pi"] * n)))
  return data, true_components
  ############################################

def give_data_with_mixes_distribs_discrete():

  num_mixes = rd.randint(2, 8)

  distributions = ["Poisson", "Bernoulli"]
  components = []

  true_components = []
  sum = 0
  for i in range(num_mixes):
        distr = rd.choice(distributions)
        pdf_f, param = pick_distribution(distr)
        pi_i = rd.uniform(0, 1 - sum)
        sum += pi_i
        true_components.append({
            "distr name": distr,
            "pdf": pdf_f,
            "params": param,
            "pi": pi_i
        })
  # create data
  data = []
  n = rd.randint(5, 1000)
  for comp in true_components:
    if comp["distr name"] == "Poisson":
      data += list(np.random.poisson(comp["params"][0], size=int(comp["pi"] * n)))
    if comp["distr name"] == "Bernoulli":
      data += list(np.random.binomial(1, comp["params"][0], size=int(comp["pi"] * n)))
    if comp["distr name"] == "Binomial":
      data += list(np.random.binomial(comp["params"][0], comp["params"][1], size=int(comp["pi"] * n)))
  return data, true_components
  ############################################

def do_test(iter = 10):

  num_test = 20

  difflistpi = []
  for i in range(num_test):
    decide = rd.randint(0, 1)
    if decide == 0:
      data, true_components = give_data_with_mixes_distribs_continuous()
      MCMC_pi = EM_MCMC(data, true_components, iter)
      EM_pi = EM(data, true_components, iter)
    if decide == 1:
      data, true_components = give_data_with_mixes_distribs_discrete()
      MCMC_pi = EM_MCMC(data, true_components, iter)
      EM_pi = EM(data, true_components, iter)
    #differences in pi
    diff_pi = [abs(MCMC_pi[i] - EM_pi[i]) for i in range(len(MCMC_pi))]
    #list of differences
    difflistpi.append(sum(diff_pi))
    print([round(diff, 6) for diff in diff_pi])

  plt.scatter(range(len(difflistpi)), difflistpi, label='')
  plt.xlabel("Iteration")
  plt.ylabel("Difference in pi values")
  plt.legend()
  plt.show()

do_test()
# Out:
# [np.float64(0.082147), np.float64(0.101683), np.float64(0.145613), np.float64(0.059509), np.float64(0.08594), np.float64(0.007988), np.float64(0.099244)]
# [np.float64(0.081097), np.float64(0.090514), np.float64(0.012633), np.float64(0.003216)]
# [np.float64(0.137734), np.float64(0.065816), np.float64(0.118974), np.float64(0.290399), np.float64(0.02681), np.float64(0.179012)]
# [np.float64(0.046998), np.float64(0.05933), np.float64(0.054275), np.float64(0.10649), np.float64(0.289336), np.float64(0.125762), np.float64(0.099027)]
# [np.float64(0.028438), np.float64(0.009701), np.float64(0.036407), np.float64(0.092991), np.float64(0.111137), np.float64(0.090436), np.float64(0.017648), np.float64(0.036971)]
# [np.float64(0.034735), np.float64(0.004012), np.float64(0.061815), np.float64(0.082722), np.float64(0.133587), np.float64(0.054449), np.float64(0.007867), np.float64(0.034518)]
# [np.float64(0.019173), np.float64(0.07344), np.float64(0.010257), np.float64(0.041413), np.float64(0.013679), np.float64(0.014498), np.float64(0.012766)]
# [np.float64(0.880132), np.float64(0.050082), np.float64(0.83005)]
# [np.float64(0.106004), np.float64(0.008466), np.float64(0.029196), np.float64(0.123091), np.float64(0.028643), np.float64(0.032286)]
# [np.float64(0.00295), np.float64(0.00295)]
# [np.float64(0.030714), np.float64(0.128686), np.float64(0.018756), np.float64(0.027688), np.float64(0.036771), np.float64(0.014757)]
# [np.float64(0.443155), np.float64(0.197531), np.float64(0.640686)]
# [np.float64(0.087569), np.float64(0.000114), np.float64(0.090977), np.float64(0.01953), np.float64(0.0035), np.float64(0.050899), np.float64(0.031347)]
# [np.float64(0.077873), np.float64(0.028758), np.float64(0.0225), np.float64(0.022229), np.float64(0.024769), np.float64(0.055803), np.float64(0.026329)]
# [np.float64(0.386576), np.float64(0.02353), np.float64(0.363046)]
# [np.float64(0.016452), np.float64(0.089946), np.float64(0.106398)]
# [np.float64(0.023462), np.float64(0.05953), np.float64(0.102252), np.float64(0.207492), np.float64(0.276966), np.float64(0.054264), np.float64(0.01503), np.float64(0.185063)]
# [np.float64(0.048193), np.float64(0.048318), np.float64(0.014374), np.float64(0.042373), np.float64(0.043722), np.float64(0.034128), np.float64(0.038856), np.float64(0.020576)]
# [np.float64(0.27623), np.float64(0.27623)]
# [np.float64(0.003899), np.float64(0.040158), np.float64(0.03175), np.float64(0.054907), np.float64(0.074478), np.float64(0.087579)]
# /tmp/ipython-input-21-592385552.py:376: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# This uses the fact that we know what distributions are being generated to our advantage. It also utilizes the random function for multiple decisions - if we are going discrete or if not (decided to seperate because of the experiment that happened earlier when combining the 2 together).
#
# Chatgpt was used here for cleanup of the code in the previous segments, in which I had to argue for it to not do too much to the code.
#
# The graph shows the absolute differences in our finished mixing weights for each mixing we randomly selected. We see that the differences are quite random, which is what we should expect - the graph doesn't serve much meaning, only for a look into seeing what is happening under the hood more.

# %% [markdown]
# From our brief analysid of these 2 method for Expectation Maximizimation, I've found that:
#
# - The Monte Carlo method requires more computation and has higher complexity than that of the Normal EM.
#
# - That being said, Monte Carlo gave surprisingly similar results, making it a viable alternative for EM.

# %% [markdown]
# AI USE:
#
# MODEL(S): CHATGPT 4o
# DATE: JULY 18TH-22ND
# PROMPTS ENTERED:
#
# - "computing MLE for a mixture of distributions from dat
#
#
# - "what is this log likelihood telling us for this iteration"
#
# - "why would the sum be 0 if the data fit perfected"
#
#
# - "give me a good dataset to use this on"
#
# - "this doesnt seem to give me accurate results"
#
# - "lambda x, mu=mu, sigma=sigma:
# what does this line mean"
#
# - "are u talking about it being (count_i + 1e-6) / total? for 4."
#
# - "is there possibly other problems in my code"
#
# - "is there a trendline function for plt"
#
# - "coeffs = np.polyfit(range(len(ll_list)), ll_list, deg=3)
#   trendline = np.poly(coeffs)
# does this work"
#
# - "Component 1: Poisson, count = 236
#
#   Component 2: Exponential, count = 17088
#
#   ...
#
#   Final parameters:
#   Component 1: Normal
#   Parameters: 2.0323434577749007 0.5859832865135821
#   Weight: 0.42520000003333336
#
#   Component 2: Poisson
#   Parameters: 5.834782608695652
#   Weight: 0.0076666667
#
#   Component 3: Exponential
#   Parameters: 2.442350628306393
#   Weight: 0.5671333333666667
#
#   what can u say about this information and the problems with the mixtures"
#
# - "how would I change my poission initialization"
#
# - "Its better, but still seeing problems with poisson"
#
# - "what is the formula for responsibilities"
#
# - "If we have data that is from a binomial distribution that we don't know what p is, how can we estimate p"
#
# - "how would we do update of params in binomial"
#
# - "... Iteration 26: Log-likelihood = -1088.0312403030805
#   Component 0: Poisson, count = 18000
#   Component 1: Binomial, count = 12000
#
#   Iteration 27: Log-likelihood = -1088.0312403030805
#   Component 0: Poisson, count = 18000
#   Component 1: Binomial, count = 12000
#
#   Iteration 28: Log-likelihood = -1088.0312403030805
#   Component 0: Poisson, count = 18000
#   Component 1: Binomial, count = 12000
#
#   Iteration 29: Log-likelihood = -1088.0312403030805
#   Component 0: Poisson, count = 18000
#   Component 1: Binomial, count = 12000
#
#   Iteration 30: Log-likelihood = -1088.0312403030805
#
#   why output do this"
#
#
# - "clean up this code and make it look nice, and provide comments and help to all the functions"
#
# - "u removed the try and except things in here, doesn't that cause issues if I pick something bad"
#
# - "clean up this code and make it look nice, and provide comments and help to all the functions
# I TOLD YOU NOT TO REMOVE ANYTHING AND YOU REMOVED THE TRY AND EXCEPT, KEEP IT IN AND STILL MAKE EVERYTHING LOOK PRETTY AND HAVE AA HELP FOR FUNCTIONS"
#
# - "now comment on this code and clean it up"
#
# - "convert this such that all the user inputs are done by the computer for a given answer"
#
# - "how do classes work"
#
# - "can you change the name of the functions such that none of them have the same name, u will also have to look through the code for old function name and change that "
#
# - "am I missing anything, I want to make random samples of random mixes of either discrete or continuous mixes and then test the differences in pi with EM and EM MCMC ways"
#
# - "What are all the steps associated in expectation maximization"
#
# - "The M-step: We update the mixing weights by the average of the probability of data point $x$ coming from distribution $j$ for all $x$ in the data set.
#
#   is this worded right?"
#
# - "can u put this in Latex"

# %% [markdown]
# #Catalog/Backup

# %% [markdown]
# # Making Random Mixes and testing both EM and EMMC and comparing

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import math
#---------------- Distribution Picker ----------------#
def pick_distribution(answer):
    """
    Automatically assigns parameters and returns (pdf, param_tuple)
    based on the chosen distribution name.
    """

    if answer == "Uniform":
        a0 = random.randint(0, 5)
        b0 = random.randint(a0 + 1, a0 + 8)  # ensure b > a
        def pdf(x): return 1 / (b0 - a0) if a0 <= x <= b0 else 0
        return pdf, (a0, b0)

    if answer == "Exponential":
        theta0 = random.uniform(0.5, 5.0)
        def pdf(x): return (1 / theta0) * math.exp(-x / theta0) if x >= 0 else 0
        return pdf, (theta0,)

    if answer == "Normal":
        mu0 = random.uniform(-5, 5)
        sigma0 = random.uniform(0.5, 3.0)
        def pdf(x): return (1 / (sigma0 * math.sqrt(2 * math.pi))) * math.exp(-(x - mu0)**2 / (2 * sigma0**2))
        return pdf, (mu0, sigma0)

    if answer == "Poisson":
        lambda_val = random.uniform(1, 8)
        def pdf(x):
            if x >= 0 and float(x).is_integer():
                x_int = int(x)
                log_pdf = -lambda_val + x_int * math.log(lambda_val) - math.lgamma(x_int + 1)
                return math.exp(log_pdf)
            return 0
        return pdf, (lambda_val,)

    if answer == "Bernoulli":
        p = random.uniform(0.1, 0.9)
        def pdf(x): return p if x == 1 else (1 - p) if x == 0 else 0
        return pdf, (p,)

    raise ValueError(f"Unsupported distribution name: {answer}")

#########################################EM Normal###############################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################

#---------------- PDF Updater ----------------#
def update_pdfs(components):
    """
    After parameter updates, refresh each component's PDF.
    """
    for comp in components:
        name = comp["distr name"]
        params = comp["params"]

        if name == "Normal":
            mu, sigma = params
            comp["pdf"] = lambda x, mu=mu, sigma=sigma: (1 / (sigma * math.sqrt(2 * math.pi))) * math.exp(-(x - mu)**2 / (2 * sigma**2))

        elif name == "Poisson":
            lamb = params[0]
            comp["pdf"] = lambda x, lamb=lamb: math.exp(-lamb + x * math.log(lamb) - math.lgamma(x + 1)) if x >= 0 and float(x).is_integer() else 0

        elif name == "Exponential":
            theta = params[0]
            comp["pdf"] = lambda x, theta=theta: (1 / theta) * math.exp(-x / theta) if x >= 0 else 0

        elif name == "Uniform":
            a, b = params
            comp["pdf"] = lambda x, a=a, b=b: 1 / (b - a) if a <= x <= b else 0

        elif name == "Bernoulli":
            p = params[0]
            comp["pdf"] = lambda x, p=p: p if x == 1 else (1 - p) if x == 0 else 0
        else:
            raise ValueError(f"Unknown distribution name: {name}")

#---------------- E-step ----------------#
def e_step(data, components):
    """
    Estimate responsibilities: P(z_i = j | x_i, θ)
    """
    responsibilities = []
    for x in data:
        weighted_probs = [comp["pi"] * comp["pdf"](x) for comp in components]
        total = sum(weighted_probs)
        probs = [wp / total for wp in weighted_probs] if total > 0 else [1 / len(components)] * len(components)
        responsibilities.append(probs)
    return responsibilities

#---------------- M-step ----------------#
def m_step(data, responsibilities, components):
    """
    Update weights and distribution parameters based on responsibilities.
    """
    n = len(data)
    k = len(components)

    for i in range(k):
        r_i = [resp[i] for resp in responsibilities]
        total_r = sum(r_i)
        components[i]["pi"] = total_r / n if total_r > 0 else 1e-6

        weighted_data = [x * r for x, r in zip(data, r_i)]

        name = components[i]["distr name"]

        if name == "Uniform":
            if np.sum(r_i) > 0:
                x_array = np.array(data)
                components[i]["params"] = (np.min(x_array), np.max(x_array))

        elif name == "Exponential" and total_r > 0:
            theta = sum(weighted_data) / total_r
            components[i]["params"] = (theta,)

        elif name == "Normal" and total_r > 0:
            mu = sum(weighted_data) / total_r
            var = sum(r * ((x - mu)**2) for x, r in zip(data, r_i)) / total_r
            sigma = math.sqrt(var)
            components[i]["params"] = (mu, sigma)

        elif name == "Bernoulli" and total_r > 0:
            p = sum(weighted_data) / total_r
            components[i]["params"] = (p,)

        elif name == "Poisson" and total_r > 0:
            lambda_ = sum(weighted_data) / total_r
            components[i]["params"] = (lambda_,)
    update_pdfs(components)
    return components
#########################################EM MC###############################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################

#---------------- E-Step (MCMC) ----------------#
def e_step_MCMC(data, components, steps=100):
    z_samples = []
    k = len(components)
    for x in data:
        weights = [comp["pi"] * comp["pdf"](x) for comp in components]
        total = sum(weights)
        weights = [w / total for w in weights] if total > 0 else [1 / k] * k
        z = np.random.choice(range(k), p=weights)
        chain = []
        for _ in range(steps):
            if k > 1:
                z_new = np.random.choice([j for j in range(k) if j != z])
                if components[z_new]["distr name"] in {"Poisson", "Bernoulli"} and not float(x).is_integer():
                    chain.append(z)
                    continue
                num = components[z_new]["pi"] * components[z_new]["pdf"](x)
                den = components[z]["pi"] * components[z]["pdf"](x)
                alpha = min(1, num / den if den > 0 else 1)
                if np.random.rand() < alpha:
                    z = z_new
            chain.append(z)
        z_samples.append(chain)
    return z_samples


#---------------- M-Step ----------------#
def m_step_MCMC(z_samples, components):
    flatz = [z for chain in z_samples for z in chain]
    total = len(flatz)
    eps = 1e-6
    min_weight = 0.05
    for i in range(len(components)):
        count_i = flatz.count(i)
        pi_i = (count_i + eps) / total
        components[i]["pi"] = max(min_weight, pi_i)
    total_pi = sum(comp["pi"] for comp in components)
    for comp in components:
        comp["pi"] /= total_pi
    return components


#---------------- Update Parameters ----------------#
def update_params_pdfs(data, components, z_samples):
    flat_x = [x for i, x in enumerate(data) for _ in z_samples[i]]
    flat_z = [z for chain in z_samples for z in chain]
    for i, comp in enumerate(components):
        spec_data = [x for x, z in zip(flat_x, flat_z) if z == i]
        if not spec_data:
            continue
        name = comp["distr name"]
        if name == "Uniform":
            comp["params"] = (min(spec_data), max(spec_data))
        elif name == "Exponential":
            comp["params"] = (np.mean(spec_data),)
        elif name == "Normal":
            comp["params"] = (np.mean(spec_data), np.std(spec_data))
        elif name == "Bernoulli":
            comp["params"] = (np.mean(spec_data),)
        elif name == "Poisson":
            comp["params"] = (np.mean(spec_data),)

        # Update pdfs
        params = comp["params"]
        if name == "Normal":
            mu, sigma = params
            comp["pdf"] = lambda x, mu=mu, sigma=sigma: (1 / (sigma * math.sqrt(2 * math.pi))) * math.exp(-(x - mu)**2 / (2 * sigma**2))
        elif name == "Poisson":
            lamb = params[0]
            comp["pdf"] = lambda x, lamb=lamb: math.exp(-lamb + x * math.log(lamb) - math.lgamma(x + 1)) if x >= 0 and float(x).is_integer() else 0
        elif name == "Exponential":
            theta = params[0]
            comp["pdf"] = lambda x, theta=theta: (1 / theta) * math.exp(-x / theta) if x >= 0 else 0
        elif name == "Uniform":
            a, b = params
            comp["pdf"] = lambda x, a=a, b=b: 1 / (b - a) if a <= x <= b else 0
        elif name == "Bernoulli":
            p = params[0]
            comp["pdf"] = lambda x, p=p: p if x == 1 else (1 - p) if x == 0 else 0
    return components

#---------------- EM-MCMC Main ----------------#
def EM_MCMC(data, true_comps, iter = 25):

    complen = len(true_comps)
    components = []
    for i in range(complen):
      distr = true_comps[i]["distr name"]
      pdf_f, param = pick_distribution(distr)
      components.append({
          "distr name": distr,
          "pdf": pdf_f,
          "params": param,
          "pi": 1/complen # we assume dont know the exact mix of the data
      })

    for i in range(iter):
        z_samples = e_step_MCMC(data, components)
        components = m_step_MCMC(z_samples, components)
        components = update_params_pdfs(data, components, z_samples)

    return [components[i]['pi'] for i in range(complen)]

#---------------- EM Main ----------------#
def EM(data, true_comps, iter = 25):

    num_components = len(true_comps)
    components = []
    for i in range(num_components):
        distr = true_comps[i]["distr name"]
        pdf_f, param = pick_distribution(distr)
        components.append({
            "distr name": distr,
            "pdf": pdf_f,
            "params": param,
            "pi": 1 / num_components
        })

    for i in range(iter):
        responsibilities = e_step(data, components)
        components = m_step(data, responsibilities, components)

    return [components[i]['pi'] for i in range(num_components)]



import random as rd


def give_data_with_mixes_distribs_continuous():

  num_mixes = rd.randint(2, 8)

  distributions = ["Uniform", "Exponential", "Normal"]
  components = []

  true_components = []
  sum = 0
  for i in range(num_mixes):
        distr = rd.choice(distributions)
        pdf_f, param = pick_distribution(distr)
        pi_i = rd.uniform(0, 1 - sum)
        sum += pi_i
        true_components.append({
            "distr name": distr,
            "pdf": pdf_f,
            "params": param,
            "pi": pi_i
        })
  # create data
  data = []
  n = rd.randint(5, 1000)
  for comp in true_components:
    if comp["distr name"] == "Uniform":
      data += list(np.random.uniform(comp["params"][0], comp["params"][1], size=int(comp["pi"] * n)))
    if comp["distr name"] == "Exponential":
      data += list(np.random.exponential(comp["params"][0], size=int(comp["pi"] * n)))
    if comp["distr name"] == "Normal":
      data += list(np.random.normal(comp["params"][0], comp["params"][1], size=int(comp["pi"] * n)))
  return data, true_components
  ############################################

def give_data_with_mixes_distribs_discrete():

  num_mixes = rd.randint(2, 8)

  distributions = ["Poisson", "Bernoulli"]
  components = []

  true_components = []
  sum = 0
  for i in range(num_mixes):
        distr = rd.choice(distributions)
        pdf_f, param = pick_distribution(distr)
        pi_i = rd.uniform(0, 1 - sum)
        sum += pi_i
        true_components.append({
            "distr name": distr,
            "pdf": pdf_f,
            "params": param,
            "pi": pi_i
        })
  # create data
  data = []
  n = rd.randint(5, 1000)
  for comp in true_components:
    if comp["distr name"] == "Poisson":
      data += list(np.random.poisson(comp["params"][0], size=int(comp["pi"] * n)))
    if comp["distr name"] == "Bernoulli":
      data += list(np.random.binomial(1, comp["params"][0], size=int(comp["pi"] * n)))
    if comp["distr name"] == "Binomial":
      data += list(np.random.binomial(comp["params"][0], comp["params"][1], size=int(comp["pi"] * n)))
  return data, true_components
  ############################################

def do_test(iter = 25):

  num_test = 20

  difflistpi = []
  for i in range(num_test):
    decide = rd.randint(0, 1)
    if decide == 0:
      data, true_components = give_data_with_mixes_distribs_continuous()
      MCMC_pi = EM_MCMC(data, true_components, iter)
      EM_pi = EM(data, true_components, iter)
    if decide == 1:
      data, true_components = give_data_with_mixes_distribs_discrete()
      MCMC_pi = EM_MCMC(data, true_components, iter)
      EM_pi = EM(data, true_components, iter)
    #differences in pi
    diff_pi = [abs(MCMC_pi[i] - EM_pi[i]) for i in range(len(MCMC_pi))]
    #list of differences
    difflistpi.append(sum(diff_pi))
    print([round(diff, 6) for diff in diff_pi])

  plt.scatter(range(len(difflistpi)), difflistpi, label='')
  plt.xlabel("Iteration")
  plt.ylabel("Difference in pi values")
  plt.legend()
  plt.show()

do_test()
# Out:
# [0.292962, 0.041603, 0.21353, 0.041603, 0.041603, 0.086983, 0.041603]
# [np.float64(0.340845), np.float64(0.002528), np.float64(0.312704), np.float64(0.028915), np.float64(0.059585)]
# [np.float64(0.311314), np.float64(0.311314)]
# [np.float64(0.276726), np.float64(0.041143), np.float64(0.00489), np.float64(0.007918), np.float64(0.024254), np.float64(0.214357)]
# [np.float64(0.011851), np.float64(0.205557), np.float64(0.192482), np.float64(0.026886), np.float64(0.051812)]
# [np.float64(0.338182), np.float64(0.153115), np.float64(0.060528), np.float64(0.245595)]
# [np.float64(0.037569), np.float64(0.035198), np.float64(0.050766), np.float64(0.109675), np.float64(0.070213), np.float64(0.056356)]
# [np.float64(0.091455), np.float64(0.014819), np.float64(0.02158), np.float64(0.055056)]
# [np.float64(0.009074), np.float64(0.112179), np.float64(0.007831), np.float64(0.060036), np.float64(0.015887), np.float64(0.066787)]
# [np.float64(0.128038), np.float64(0.30709), np.float64(0.087964), np.float64(0.091088)]
# [np.float64(0.636921), np.float64(0.03131), np.float64(0.903684), np.float64(0.17117), np.float64(0.032796), np.float64(0.031487)]
# [np.float64(0.100746), np.float64(0.067993), np.float64(0.041918), np.float64(0.009165)]
# [np.float64(0.120448), np.float64(0.08009), np.float64(0.163182), np.float64(0.36372)]
# [np.float64(0.177789), np.float64(0.012972), np.float64(0.248762), np.float64(0.036239), np.float64(0.120184)]
# [np.float64(0.385455), np.float64(0.068608), np.float64(0.116074), np.float64(0.200773)]
# [np.float64(0.33936), np.float64(0.088914), np.float64(0.005723), np.float64(0.33767), np.float64(0.017744), np.float64(0.067137)]
# [np.float64(0.035121), np.float64(0.039617), np.float64(0.004359), np.float64(0.017401), np.float64(0.026255)]
# [np.float64(0.013874), np.float64(0.005178), np.float64(0.008696)]
# [np.float64(0.454785), np.float64(0.015852), np.float64(0.588065), np.float64(0.078483), np.float64(0.017379), np.float64(0.000357), np.float64(0.045963), np.float64(0.102644)]
# [np.float64(0.047788), np.float64(0.057559), np.float64(0.240283), np.float64(0.093487), np.float64(0.192185), np.float64(0.0447), np.float64(0.183159), np.float64(0.190752)]
# /tmp/ipython-input-15-4210692911.py:376: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # Using MCMC instead of Normal EM

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import math

#########################################EM MC###############################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#---------------- Safe Binomial PDF ----------------#
def binomial_pdf_safe(x, n, p):
    """Computes binomial PMF using log-form to avoid overflow."""
    if 0 <= x <= n:
        try:
            log_pdf = (math.lgamma(n + 1)
                       - math.lgamma(x + 1)
                       - math.lgamma(n - x + 1)
                       + x * math.log(p)
                       + (n - x) * math.log(1 - p))
            return math.exp(log_pdf)
        except (ValueError, OverflowError):
            return 0
    return 0


#---------------- Distribution Picker ----------------#
def pick_distribution(answer):
    """
    Prompts user for parameters of the chosen distribution.
    Returns a tuple: (pdf function, parameter tuple)
    """

    if answer == "Uniform":
        while True:
            try:
                a0 = float(input("Initial lower bound guess: "))
                break
            except ValueError:
                print("Invalid input. Please enter a number.")
        while True:
            try:
                b0 = float(input("Initial upper bound guess: "))
                break
            except ValueError:
                print("Invalid input. Please enter a number.")
        def pdf(x): return 1 / (b0 - a0) if a0 <= x <= b0 else 0
        return pdf, (a0, b0)

    if answer == "Exponential":
        while True:
            try:
                theta0 = float(input("Enter the mean guess: "))
                break
            except ValueError:
                print("Invalid input. Please enter a number.")
        def pdf(x): return (1 / theta0) * math.exp(-x / theta0) if x >= 0 else 0
        return pdf, (theta0,)

    if answer == "Normal":
        while True:
            try:
                mu0 = float(input("Enter the mean guess: "))
                break
            except ValueError:
                print("Invalid input. Please enter a number.")
        while True:
            try:
                sigma0 = float(input("Enter the standard deviation guess: "))
                break
            except ValueError:
                print("Invalid input. Please enter a number.")
        def pdf(x): return (1 / (sigma0 * math.sqrt(2 * math.pi))) * math.exp(-(x - mu0)**2 / (2 * sigma0**2))
        return pdf, (mu0, sigma0)

    if answer == "Poisson":
        integer_data = [x for x in data if float(x).is_integer()]
        estimated_lambda = np.mean(integer_data) if integer_data else 3.0
        print(f"Suggested lambda (from integer data): {estimated_lambda:.2f}")
        while True:
            try:
                lambda_val = float(input("Enter the Poisson mean (lambda): "))
                if lambda_val > 0:
                    break
                else:
                    print("Lambda must be greater than 0.")
            except ValueError:
                print("Invalid input. Please enter a number.")
        def pdf(x):
            if x >= 0 and float(x).is_integer():
                x_int = int(x)
                log_pdf = -lambda_val + x_int * math.log(lambda_val) - math.lgamma(x_int + 1)
                return math.exp(log_pdf)
            return 0
        return pdf, (lambda_val,)

    if answer == "Bernoulli":
        while True:
            try:
                p = float(input("Enter probability of success (0 < p < 1): "))
                if 0 < p < 1:
                    break
                else:
                    print("p must be between 0 and 1.")
            except ValueError:
                print("Invalid input. Please enter a number.")
        def pdf(x): return p if x == 1 else (1 - p) if x == 0 else 0
        return pdf, (p,)

    if answer == "Binomial":
        n = 300  # Reasonable default
        while True:
            try:
                p = float(input("Enter probability of success (0 < p < 1): "))
                if 0 < p < 1:
                    break
                else:
                    print("p must be between 0 and 1.")
            except ValueError:
                print("Invalid input. Please enter a number.")
        def pdf(x): return binomial_pdf_safe(x, n, p)
        return pdf, (n, p)


#---------------- E-Step (MCMC) ----------------#
def e_step_MCMC(data, components, steps=100):
    z_samples = []
    k = len(components)
    for x in data:
        weights = [comp["pi"] * comp["pdf"](x) for comp in components]
        total = sum(weights)
        weights = [w / total for w in weights] if total > 0 else [1 / k] * k
        z = np.random.choice(range(k), p=weights)
        chain = []
        for _ in range(steps):
            if k > 1:
                z_new = np.random.choice([j for j in range(k) if j != z])
                if components[z_new]["distr name"] in {"Poisson", "Bernoulli", "Binomial"} and not float(x).is_integer():
                    chain.append(z)
                    continue
                num = components[z_new]["pi"] * components[z_new]["pdf"](x)
                den = components[z]["pi"] * components[z]["pdf"](x)
                alpha = min(1, num / den if den > 0 else 1)
                if np.random.rand() < alpha:
                    z = z_new
            chain.append(z)
        z_samples.append(chain)
    return z_samples


#---------------- M-Step ----------------#
def m_step_MCMC(z_samples, components):
    flatz = [z for chain in z_samples for z in chain]
    total = len(flatz)
    eps = 1e-6
    min_weight = 0.05
    for i in range(len(components)):
        count_i = flatz.count(i)
        pi_i = (count_i + eps) / total
        components[i]["pi"] = max(min_weight, pi_i)
    total_pi = sum(comp["pi"] for comp in components)
    for comp in components:
        comp["pi"] /= total_pi
    return components


#---------------- Update Parameters ----------------#
def update_params_pdfs(data, components, z_samples):
    flat_x = [x for i, x in enumerate(data) for _ in z_samples[i]]
    flat_z = [z for chain in z_samples for z in chain]
    for i, comp in enumerate(components):
        spec_data = [x for x, z in zip(flat_x, flat_z) if z == i]
        if not spec_data:
            continue
        name = comp["distr name"]
        if name == "Uniform":
            comp["params"] = (min(spec_data), max(spec_data))
        elif name == "Exponential":
            comp["params"] = (np.mean(spec_data),)
        elif name == "Normal":
            comp["params"] = (np.mean(spec_data), np.std(spec_data))
        elif name == "Bernoulli":
            comp["params"] = (np.mean(spec_data),)
        elif name == "Poisson":
            comp["params"] = (np.mean(spec_data),)
        elif name == "Binomial":
            n_old, _ = comp["params"]
            n = max(int(n_old), int(np.percentile(spec_data, 95)))
            p_est = np.mean(spec_data) / n if n > 0 else 1e-6
            p_est = max(1e-6, min(1 - 1e-6, p_est))
            comp["params"] = (n, p_est)

        # Update pdfs
        params = comp["params"]
        if name == "Normal":
            mu, sigma = params
            comp["pdf"] = lambda x, mu=mu, sigma=sigma: (1 / (sigma * math.sqrt(2 * math.pi))) * math.exp(-(x - mu)**2 / (2 * sigma**2))
        elif name == "Poisson":
            lamb = params[0]
            comp["pdf"] = lambda x, lamb=lamb: math.exp(-lamb + x * math.log(lamb) - math.lgamma(x + 1)) if x >= 0 and float(x).is_integer() else 0
        elif name == "Exponential":
            theta = params[0]
            comp["pdf"] = lambda x, theta=theta: (1 / theta) * math.exp(-x / theta) if x >= 0 else 0
        elif name == "Uniform":
            a, b = params
            comp["pdf"] = lambda x, a=a, b=b: 1 / (b - a) if a <= x <= b else 0
        elif name == "Bernoulli":
            p = params[0]
            comp["pdf"] = lambda x, p=p: p if x == 1 else (1 - p) if x == 0 else 0
        elif name == "Binomial":
            n, p = params
            comp["pdf"] = lambda x, n=n, p=p: binomial_pdf_safe(x, n, p)
    return components


#---------------- Log-Likelihood ----------------#
def compute_log_likelihood(data, components):
    log_likelihood = 0
    for x in data:
        mix_prob = sum(comp["pi"] * comp["pdf"](x) for comp in components)
        if mix_prob > 0:
            log_likelihood += math.log(mix_prob)
    return log_likelihood


#---------------- EM-MCMC Main ----------------#
def EM_MCMC(data, num_iters):
    num_components = int(input("How many distributions would you like to mix? "))
    components = []
    for i in range(num_components):
        distr = ""
        while distr not in ["Uniform", "Exponential", "Normal", "Poisson", "Bernoulli", "Binomial"]:
            distr = input(f"Choose distribution {i+1}: ")
        pdf_f, param = pick_distribution(distr)
        components.append({"distr name": distr, "pdf": pdf_f, "params": param, "pi": 1 / num_components})

    ll_list = []
    for i in range(num_iters):
        z_samples = e_step_MCMC(data, components)
        components = m_step_MCMC(z_samples, components)
        components = update_params_pdfs(data, components, z_samples)
        ll = compute_log_likelihood(data, components)
        ll_list.append(ll)
        if i > 0:
            print(f"Iteration {i+1}: Log-likelihood = {ll:.4f}")

    # Plot log-likelihood
    plt.figure(figsize=(10, 6))
    plt.scatter(range(len(ll_list)), ll_list, label='Log-Likelihood')
    trendline = np.poly1d(np.polyfit(range(len(ll_list)), ll_list, deg=3))
    plt.plot(range(len(ll_list)), trendline(range(len(ll_list))), color='blue', label='Trendline')
    plt.xlabel("Iteration")
    plt.ylabel("Log-Likelihood")
    plt.legend()
    plt.show()

    # Final parameter output
    print("\nFinal Parameters:")
    for i, comp in enumerate(components):
        print(f"Component {i+1}: {comp['distr name']}")
        print("  Parameters:", *(round(float(x), 4) for x in comp["params"]))
        print("  Weight:    ", round(float(comp["pi"]), 4))
        print()


#---------------- Entry Point ----------------#
np.random.seed(924)
n = 300
data = []
data += list(np.random.poisson(3, size=int(0.4 * n)))
data += list(np.random.binomial(300, 0.5, size=int(0.6 * n)))
random.shuffle(data)

# Run
EM_MCMC(data, 20)
# Out:
# How many distributions would you like to mix? 2
# Choose distribution 1: Poisson
# Suggested lambda (from integer data): 91.47
# Enter the Poisson mean (lambda): 2
# Choose distribution 2: Binomial
# Enter probability of success (0 < p < 1): 0.2
# Iteration 2: Log-likelihood = -1062.8829
# Iteration 3: Log-likelihood = -1062.8829
# Iteration 4: Log-likelihood = -1062.8829
# Iteration 5: Log-likelihood = -1062.8829
# Iteration 6: Log-likelihood = -1062.8829
# Iteration 7: Log-likelihood = -1062.8829
# Iteration 8: Log-likelihood = -1062.8829
# Iteration 9: Log-likelihood = -1062.8829
# Iteration 10: Log-likelihood = -1062.8829
# Iteration 11: Log-likelihood = -1062.8829
# Iteration 12: Log-likelihood = -1062.8829
# Iteration 13: Log-likelihood = -1062.8829
# Iteration 14: Log-likelihood = -1062.8829
# Iteration 15: Log-likelihood = -1062.8829
# Iteration 16: Log-likelihood = -1062.8829
# Iteration 17: Log-likelihood = -1062.8829
# Iteration 18: Log-likelihood = -1062.8829
# Iteration 19: Log-likelihood = -1062.8829
# Iteration 20: Log-likelihood = -1062.8829
# Final Parameters:
# Component 1: Poisson
#   Parameters: 3.0
#   Weight:     0.4
#
# Component 2: Binomial
#   Parameters: 300.0 0.5015
#   Weight:     0.6

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import math

#########################################EM Normal###############################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#################################################################################################
#---------------- Distribution Picker ----------------#
def pick_distribution(answer):
    """
    Asks the user for parameters depending on the distribution type.
    Returns a PDF function and its initial parameters.
    """

    # Continuous Distributions ----------------------------

    if answer == "Uniform":
        while True:
            try:
                a0 = float(input("Initial lower bound guess: "))
                break
            except ValueError:
                print("Invalid input. Please enter a number.")
        while True:
            try:
                b0 = float(input("Initial upper bound guess: "))
                break
            except ValueError:
                print("Invalid input. Please enter a number.")
        def pdf(x):
            return 1 / (b0 - a0) if a0 <= x <= b0 else 0
        return pdf, (a0, b0)

    if answer == "Exponential":
        while True:
            try:
                theta0 = float(input("Enter the mean guess: "))
                break
            except ValueError:
                print("Invalid input. Please enter a number.")
        def pdf(x):
            return (1 / theta0) * math.exp(-x / theta0) if x >= 0 else 0
        return pdf, (theta0,)

    if answer == "Normal":
        while True:
            try:
                mu0 = float(input("Enter the mean guess: "))
                break
            except ValueError:
                print("Invalid input. Please enter a number.")
        while True:
            try:
                sigma0 = float(input("Enter the standard deviation guess: "))
                break
            except ValueError:
                print("Invalid input. Please enter a number.")
        def pdf(x_val):
            return (1 / (sigma0 * math.sqrt(2 * math.pi))) * math.exp(-(x_val - mu0)**2 / (2 * sigma0**2))
        return pdf, (mu0, sigma0)

    # Discrete Distributions ----------------------------

    if answer == "Poisson":
        integer_data = [x for x in data if float(x).is_integer()]
        estimated_lambda = np.mean(integer_data) if integer_data else 3.0
        print(f"Suggested lambda (from integer data): {estimated_lambda:.2f}")
        while True:
            try:
                lambda_val = float(input("Enter the Poisson mean (lambda): "))
                if lambda_val > 0:
                    break
                else:
                    print("lambda must be greater than 0.")
            except ValueError:
                print("Invalid input. Please enter a number.")
        def pdf(x):
            if x >= 0 and float(x).is_integer():
                x_int = int(x)
                log_pdf = -lambda_val + x_int * math.log(lambda_val) - math.lgamma(x_int + 1)
                return math.exp(log_pdf)
            return 0
        return pdf, (lambda_val,)

    if answer == "Bernoulli":
        while True:
            try:
                p = float(input("Enter probability of success (0 < p < 1): "))
                if 0 < p < 1:
                    break
                else:
                    print("p must be between 0 and 1.")
            except ValueError:
                print("Invalid input. Please enter a number.")
        def pdf(x):
            return p if x == 1 else (1 - p) if x == 0 else 0
        return pdf, (p,)

    if answer == "Binomial":
        n = max(data)
        while True:
            try:
                p = float(input("Enter probability of success (0 < p < 1): "))
                if 0 < p < 1:
                    break
                else:
                    print("p must be between 0 and 1.")
            except ValueError:
                print("Invalid input. Please enter a number.")
        def pdf(x):
            if 0 <= x <= n:
                return math.comb(n, x) * (p ** x) * ((1 - p) ** (n - x))
            return 0
        return pdf, (n, p)

#---------------- PDF Updater ----------------#
def update_pdfs(components):
    """
    After parameter updates, refresh each component's PDF.
    """
    for comp in components:
        name = comp["distr name"]
        params = comp["params"]

        if name == "Normal":
            mu, sigma = params
            comp["pdf"] = lambda x, mu=mu, sigma=sigma: (1 / (sigma * math.sqrt(2 * math.pi))) * math.exp(-(x - mu)**2 / (2 * sigma**2))

        elif name == "Poisson":
            lamb = params[0]
            comp["pdf"] = lambda x, lamb=lamb: math.exp(-lamb + x * math.log(lamb) - math.lgamma(x + 1)) if x >= 0 and float(x).is_integer() else 0

        elif name == "Exponential":
            theta = params[0]
            comp["pdf"] = lambda x, theta=theta: (1 / theta) * math.exp(-x / theta) if x >= 0 else 0

        elif name == "Uniform":
            a, b = params
            comp["pdf"] = lambda x, a=a, b=b: 1 / (b - a) if a <= x <= b else 0

        elif name == "Bernoulli":
            p = params[0]
            comp["pdf"] = lambda x, p=p: p if x == 1 else (1 - p) if x == 0 else 0

        elif name == "Binomial":
            n, p = params
            comp["pdf"] = lambda x, n=n, p=p: math.comb(n, x) * (p ** x) * ((1 - p) ** (n - x)) if 0 <= x <= n else 0

        else:
            raise ValueError(f"Unknown distribution name: {name}")

#---------------- E-step ----------------#
def e_step(data, components):
    """
    Estimate responsibilities: P(z_i = j | x_i, θ)
    """
    responsibilities = []
    for x in data:
        weighted_probs = [comp["pi"] * comp["pdf"](x) for comp in components]
        total = sum(weighted_probs)
        probs = [wp / total for wp in weighted_probs] if total > 0 else [1 / len(components)] * len(components)
        responsibilities.append(probs)
    return responsibilities

#---------------- M-step ----------------#
def m_step(data, responsibilities, components):
    """
    Update weights and distribution parameters based on responsibilities.
    """
    n = len(data)
    k = len(components)

    for i in range(k):
        r_i = [resp[i] for resp in responsibilities]
        total_r = sum(r_i)
        components[i]["pi"] = total_r / n if total_r > 0 else 1e-6

        weighted_data = [x * r for x, r in zip(data, r_i)]

        name = components[i]["distr name"]

        if name == "Uniform":
            if np.sum(r_i) > 0:
                x_array = np.array(data)
                components[i]["params"] = (np.min(x_array), np.max(x_array))

        elif name == "Exponential" and total_r > 0:
            theta = sum(weighted_data) / total_r
            components[i]["params"] = (theta,)

        elif name == "Normal" and total_r > 0:
            mu = sum(weighted_data) / total_r
            var = sum(r * ((x - mu)**2) for x, r in zip(data, r_i)) / total_r
            sigma = math.sqrt(var)
            components[i]["params"] = (mu, sigma)

        elif name == "Bernoulli" and total_r > 0:
            p = sum(weighted_data) / total_r
            components[i]["params"] = (p,)

        elif name == "Poisson" and total_r > 0:
            lambda_ = sum(weighted_data) / total_r
            components[i]["params"] = (lambda_,)

        elif name == "Binomial":
            n_old, _ = components[i]["params"]
            n_int = int(n_old)
            if total_r > 0:
                weighted_sum = sum(x * r for x, r in zip(data, r_i))
                p_estimate = weighted_sum / (n_int * total_r)
                p_estimate = max(1e-6, min(1 - 1e-6, p_estimate))
                components[i]["params"] = (n_int, p_estimate)

        else:
            raise ValueError(f"Unknown distribution name: {name}")

    update_pdfs(components)
    return components

#---------------- Log-Likelihood ----------------#
def compute_log_likelihood(data, components):
    """
    Computes the total log-likelihood of the current model.
    """
    ll = 0
    for x in data:
        prob = sum(comp["pi"] * comp["pdf"](x) for comp in components)
        if prob > 0:
            ll += np.log(prob)
    return ll

#---------------- EM Main ----------------#
def EM_MCMC(data, num_iters):
    """
    Expectation-Maximization algorithm for mixture models (non-MCMC version).
    """
    num_components = int(input("How many distributions would you like to mix? "))
    components = []
    for i in range(num_components):
        distr = ''
        while distr not in ["Uniform", "Exponential", "Normal", "Poisson", "Bernoulli", "Binomial"]:
            distr = input(f"Choose distribution {i+1}: ")
        pdf_f, param = pick_distribution(distr)
        components.append({
            "distr name": distr,
            "pdf": pdf_f,
            "params": param,
            "pi": 1 / num_components
        })

    ll_list = []
    for i in range(num_iters):
        responsibilities = e_step(data, components)
        components = m_step(data, responsibilities, components)
        ll = compute_log_likelihood(data, components)
        ll_list.append(ll)
        if i > 0:
            print(f"Iteration {i+1}: Log-likelihood = {ll:.4f}")

    # Plotting log-likelihood over iterations
    plt.figure(figsize=(10, 6))
    plt.scatter(range(len(ll_list)), ll_list, label='Log-Likelihood')
    trendline = np.poly1d(np.polyfit(range(len(ll_list)), ll_list, deg=3))
    plt.plot(range(len(ll_list)), trendline(range(len(ll_list))), color='blue', label='Trendline')
    plt.xlabel("Iteration")
    plt.ylabel("Log-Likelihood")
    plt.legend()
    plt.title("EM Log-Likelihood Progress")
    plt.grid(True)
    plt.show()

    # Final output
    print("\nFinal parameters:")
    for i, comp in enumerate(components):
        print(f"Component {i+1}: {comp['distr name']}")
        print("  Parameters:", *(round(float(x), 4) for x in comp["params"]))
        print("  Weight:    ", round(float(comp["pi"]), 4))
        print()

#---------------- Main Execution ----------------#
np.random.seed(924)
n = 300
data = []

# Data mixture: 40% Poisson(3), 60% Binomial(300, 0.5)
data += list(np.random.poisson(3, size=int(0.4 * n)))
data += list(np.random.binomial(300, 0.5, size=int(0.6 * n)))
random.shuffle(data)

# Run EM
EM_MCMC(data, 200)

# %% [markdown]
# # Classical EM

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import math
import functools





def pick_distribution(answer):

  #Continuous Distributions-----------------------------------------------------

  if answer == "Uniform":
    while True:
      try:
        a0 = float(input("Initial lower bound guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")
    while True:
      try:
        b0 = float(input("Initial upper bound guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")
    def pdf(x):
      return 1 / (b0 - a0) if a0 <= x <= b0 else 0

    return pdf, (a0, b0)

  if answer == "Exponential":
    while True:
      try:
        theta0 = float(input("Enter the mean guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")

    def pdf(x):
      return (1 / theta0) * math.exp(-x / theta0) if x >= 0 else 0

    return pdf, (theta0,) # Corrected parameter return

  if answer == "Normal":
    while True:
      try:
        mu0 = float(input("Enter the mean guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")
    while True:
      try:
        sigma0 = float(input("Enter the standard deviation guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")
    def pdf(x_val):
      return (1 / (sigma0 * math.sqrt(2 * math.pi))) * math.exp(-(x_val - mu0)**2 / (2 * sigma0**2))
    return pdf, (mu0, sigma0)


  #Discrete Distributions-----------------------------------------------------

  if answer == "Poisson":

    integer_data = [x for x in data if float(x).is_integer()]
    estimated_lambda = np.mean(integer_data) if integer_data else 3.0

    print(f"Suggested lambda (from integer data): {estimated_lambda:.2f}")
    while True:
        try:
            lambda_val = float(input("Enter the Poisson mean (lambda): "))
            if lambda_val > 0:
                break
            else:
                print("lambda must be greater than 0.")
        except ValueError:
            print("Invalid input. Please enter a number.")
    def pdf(x):
      if x >= 0 and float(x).is_integer():
          x_int = int(x)
          # Use log-likelihood to avoid overflow with large numbers
          log_pdf = -lambda_val + x_int * math.log(lambda_val) - math.lgamma(x_int + 1)
          return math.exp(log_pdf)
      else:
          return 0

    return pdf, (lambda_val,)

  if answer == "Bernoulli":
    while True:
        try:
            p = float(input("Enter probability of success (0 < p < 1): "))
            if 0 < p < 1:
                break
            else:
                print("p must be between 0 and 1.")
        except ValueError:
            print("Invalid input. Please enter a number.")

    def pdf(x):
        return p if x == 1 else (1 - p) if x == 0 else 0

    return pdf, (p,)

  if answer == "Binomial":
    n= max(data)
    while True:
        try:
            p = float(input("Enter probability of success (0 < p < 1): "))
            if 0 < p < 1:
                break
            else:
                print("0 < p < 1.")
        except ValueError:
            print("Invalid input. Please enter a positive number.")
    def pdf(x):
      if 0 <= x <= n:
          return math.comb(n, x) * (p ** x) * ((1 - p) ** (n - x))
      else:
          return 0

    return pdf, (n, p)

def update_pdfs(components):
    for comp in components:
        name = comp["distr name"]
        params = comp["params"]

        if name == "Normal":
            mu, sigma = params
            def f(x, mu=mu, sigma=sigma):
                return (1 / (sigma * math.sqrt(2 * math.pi))) * math.exp(-(x - mu)**2 / (2 * sigma**2))
            comp["pdf"] = f

        elif name == "Poisson":
            lamb = params[0]
            def f(x, lamb=lamb):
                if x >= 0 and float(x).is_integer():
                    x_int = int(x)
                    # Use log-likelihood to avoid overflow with large numbers
                    log_pdf = -lamb + x_int * math.log(lamb) - math.lgamma(x_int + 1)
                    return math.exp(log_pdf)
                else:
                  return 0
            comp["pdf"] = f

        elif name == "Exponential":
            theta = params[0]
            def f(x, theta=theta):
                return (1 / theta) * math.exp(-x / theta) if x >= 0 else 0
            comp["pdf"] = f

        elif name == "Uniform":
            a, b = params
            def f(x, a=a, b=b):
                return 1 / (b - a) if a <= x <= b else 0
            comp["pdf"] = f

        elif name == "Bernoulli":
            p = params[0]
            def f(x, p=p):
                return p if x == 1 else (1 - p) if x == 0 else 0
            comp["pdf"] = f
        elif name == "Binomial":
          n, p = params
          def f(x):
            if 0 <= x <= n:
              return math.comb(n, x) * (p ** x) * ((1 - p) ** (n - x))
            else:
              return 0
          comp["pdf"] = f

        else:
            raise ValueError(f"Unknown distribution name: {name}")

def e_step(data, components):
  responsibilities = []
  for x in data:
    num = [comp["pi"] * comp["pdf"](x) for comp in components]
    tot = sum(num)
    if tot == 0:
      probs = [1 / len(components)] * len(components)
    else:
      probs = [n / tot for n in num]
    responsibilities.append(probs)
  return responsibilities



def m_step(data, responsibilities, components):
    n = len(data)
    k = len(components)

    for i in range(k):
        r_i = [resp[i] for resp in responsibilities]
        total_r = sum(r_i)
        components[i]["pi"] = total_r / n if total_r > 0 else 1e-6

        spec_data = [x * r for x, r in zip(data, r_i)]

        if components[i]["distr name"] == "Uniform":
            # Weighted min/max
            weights = np.array(r_i)
            if np.sum(weights) > 0:
                x_array = np.array(data)
                components[i]["params"] = (np.min(x_array[weights > 0]), np.max(x_array[weights > 0]))
            else:
                pass # Keep previous parameters if no data points assigned to this component

        elif components[i]["distr name"] == "Exponential":
            if total_r > 0:
                theta = sum(spec_data) / total_r
                components[i]["params"] = (theta,)
            else:
                pass # Keep previous parameters if no data points assigned to this component

        elif components[i]["distr name"] == "Normal":
            if total_r > 0:
                mu = sum(spec_data) / total_r
                var = sum(r * ((x - mu)**2) for x, r in zip(data, r_i)) / total_r
                sigma = math.sqrt(var)
                components[i]["params"] = (mu, sigma)
            else:
                pass # Keep previous parameters if no data points assigned to this component

        elif components[i]["distr name"] == "Bernoulli":
            if total_r > 0:
                p = sum(spec_data) / total_r
                components[i]["params"] = (p,)
            else:
                pass # Keep previous parameters if no data points assigned to this component

        elif components[i]["distr name"] == "Poisson":
            if total_r > 0:
                lambda_ = sum(spec_data) / total_r
                components[i]["params"] = (lambda_,)
            else:
                pass # Keep previous parameters if no data points assigned to this component
        elif components[i]["distr name"] == "Binomial":

            n_old, p = components[i]["params"]
            n_int = int(n_old)  # fixed initial n

            total_r = sum(r_i)
            if total_r > 0:
              weighted_sum = sum(x * r for x, r in zip(data, r_i))
              p_estimate = weighted_sum / (n_int * total_r)
              p_estimate = max(1e-6, min(1 - 1e-6, p_estimate))
              components[i]["params"] = (n_int, p_estimate)
            else:
                pass # Keep previous parameters if no data points assigned to this component
        else:
            raise ValueError(f"Unknown distribution name: {components[i]['distr name']}")


    update_pdfs(components)
    return components


def compute_log_likelihood(data, components):
    log_likelihood = 0
    for x in data:
        mixture_prob = sum(comp['pi'] * comp['pdf'](x) for comp in components)
        if mixture_prob > 0:
            log_likelihood += np.log(mixture_prob)
    return log_likelihood


def EM_MCMC(data, num_iters):

  components = []

  # data = [0, 1, 8, 6, 2, 4] # Removed hardcoded data

  num_components = int(input("How many distributions would you like to mix? "))

  components = []
  for i in range(num_components):
    distr = ''
    while distr not in ["Uniform", "Exponential", "Normal", "Poisson", "Bernoulli", "Binomial"]:
      distr = input(f"Choose distribution {i+1}: ")
    pdf_f, param = pick_distribution(distr)
    components.append({"distr name": distr, "pdf": pdf_f, "params": param, "pi": 1 / num_components}) # --> Start by assuming that each data point has equal
                                                                                                          # chance of being associated with one of the distributions.
  ll_list = []
  for i in range(num_iters):
    responsibilities = e_step(data, components)
    components = m_step(data, responsibilities, components)

    ll = compute_log_likelihood(data, components)
    ll_list.append(ll)
    if i > 0:
      print(f"Iteration {i+1}: Log-likelihood = {ll}")

  # plot log likelihood changes
  plt.figure(figsize=(10, 6))
  plt.scatter(range(len(ll_list)), ll_list, label='Data')

  coeffs = np.polyfit(range(len(ll_list)), ll_list, deg=3)
  trendline = np.poly1d(coeffs)

  plt.plot(range(len(ll_list)), trendline(range(len(ll_list))), color='blue', label='Trendline')

  plt.xlabel("iteration")
  plt.ylabel("log likelihood")
  plt.legend()
  plt.show()

  print("Final parameters:")

  for i in range(len(components)):
    print(f"Component {i+1}: {components[i]['distr name']}")
    print("Parameters:", *(float(x) for x in components[i]['params']))
    print(f"Weight: {float(components[i]['pi'])}")
    print()
  return

np.random.seed(924)

# Generate data
n = 300
data = []

# 40% Normal(2, 0.5)
#data += list(np.random.normal(loc=2, scale=0.5, size=int(0.4 * n)))

data += list(np.random.poisson(3, size=int(0.4 * n)))
data += list(np.random.binomial(300, 0.5, size=int(0.6 * n)))

# 30% Uniform(0,5)
#data += list(np.random.uniform(0,5, size=int(0.3 * n)))

# 30% Exponential(1.5)
#data += list(np.random.exponential(scale=1.5, size=int(0.3 * n)))


random.shuffle(data)


EM_MCMC(data, 200)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-35-615531903.py in <cell line: 0>()
#     337
#     338
# --> 339 EM_MCMC(data, 200)
#
# /tmp/ipython-input-35-615531903.py in EM_MCMC(data, num_iters)
#     272   # data = [0, 1, 8, 6, 2, 4] # Removed hardcoded data
#     273
# --> 274   num_components = int(input("How many distributions would you like to mix? "))
#     275
#     276   components = []
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # OLD VERSIONS BEFORE CHATGPT CLEAN UP

# %% [markdown]
# # EM NORMAL

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import math
import functools

def pick_distribution(answer):

  #Continuous Distributions-----------------------------------------------------

  if answer == "Uniform":
    while True:
      try:
        a0 = float(input("Initial lower bound guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")
    while True:
      try:
        b0 = float(input("Initial upper bound guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")
    def pdf(x):
      return 1 / (b0 - a0) if a0 <= x <= b0 else 0

    return pdf, (a0, b0)

  if answer == "Exponential":
    while True:
      try:
        theta0 = float(input("Enter the mean guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")

    def pdf(x):
      return (1 / theta0) * math.exp(-x / theta0) if x >= 0 else 0

    return pdf, (theta0,) # Corrected parameter return

  if answer == "Normal":
    while True:
      try:
        mu0 = float(input("Enter the mean guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")
    while True:
      try:
        sigma0 = float(input("Enter the standard deviation guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")
    def pdf(x_val):
      return (1 / (sigma0 * math.sqrt(2 * math.pi))) * math.exp(-(x_val - mu0)**2 / (2 * sigma0**2))
    return pdf, (mu0, sigma0)


  #Discrete Distributions-----------------------------------------------------

  if answer == "Poisson":

    integer_data = [x for x in data if float(x).is_integer()]
    estimated_lambda = np.mean(integer_data) if integer_data else 3.0

    print(f"Suggested lambda (from integer data): {estimated_lambda:.2f}")
    while True:
        try:
            lambda_val = float(input("Enter the Poisson mean (lambda): "))
            if lambda_val > 0:
                break
            else:
                print("lambda must be greater than 0.")
        except ValueError:
            print("Invalid input. Please enter a number.")
    def pdf(x):
      if x >= 0 and float(x).is_integer():
          x_int = int(x)
          # Use log-likelihood to avoid overflow with large numbers
          log_pdf = -lambda_val + x_int * math.log(lambda_val) - math.lgamma(x_int + 1)
          return math.exp(log_pdf)
      else:
          return 0

    return pdf, (lambda_val,)

  if answer == "Bernoulli":
    while True:
        try:
            p = float(input("Enter probability of success (0 < p < 1): "))
            if 0 < p < 1:
                break
            else:
                print("p must be between 0 and 1.")
        except ValueError:
            print("Invalid input. Please enter a number.")

    def pdf(x):
        return p if x == 1 else (1 - p) if x == 0 else 0

    return pdf, (p,)

  if answer == "Binomial":
    n= max(data)
    while True:
        try:
            p = float(input("Enter probability of success (0 < p < 1): "))
            if 0 < p < 1:
                break
            else:
                print("0 < p < 1.")
        except ValueError:
            print("Invalid input. Please enter a positive number.")
    def pdf(x):
      if 0 <= x <= n:
          return math.comb(n, x) * (p ** x) * ((1 - p) ** (n - x))
      else:
          return 0

    return pdf, (n, p)

def update_pdfs(components):
    for comp in components:
        name = comp["distr name"]
        params = comp["params"]

        if name == "Normal":
            mu, sigma = params
            def f(x, mu=mu, sigma=sigma):
                return (1 / (sigma * math.sqrt(2 * math.pi))) * math.exp(-(x - mu)**2 / (2 * sigma**2))
            comp["pdf"] = f

        elif name == "Poisson":
            lamb = params[0]
            def f(x, lamb=lamb):
                if x >= 0 and float(x).is_integer():
                    x_int = int(x)
                    # Use log-likelihood to avoid overflow with large numbers
                    log_pdf = -lamb + x_int * math.log(lamb) - math.lgamma(x_int + 1)
                    return math.exp(log_pdf)
                else:
                  return 0
            comp["pdf"] = f

        elif name == "Exponential":
            theta = params[0]
            def f(x, theta=theta):
                return (1 / theta) * math.exp(-x / theta) if x >= 0 else 0
            comp["pdf"] = f

        elif name == "Uniform":
            a, b = params
            def f(x, a=a, b=b):
                return 1 / (b - a) if a <= x <= b else 0
            comp["pdf"] = f

        elif name == "Bernoulli":
            p = params[0]
            def f(x, p=p):
                return p if x == 1 else (1 - p) if x == 0 else 0
            comp["pdf"] = f
        elif name == "Binomial":
          n, p = params
          def f(x):
            if 0 <= x <= n:
              return math.comb(n, x) * (p ** x) * ((1 - p) ** (n - x))
            else:
              return 0
          comp["pdf"] = f

        else:
            raise ValueError(f"Unknown distribution name: {name}")

def e_step(data, components):
  responsibilities = []
  for x in data:
    num = [comp["pi"] * comp["pdf"](x) for comp in components]
    tot = sum(num)
    if tot == 0:
      probs = [1 / len(components)] * len(components)
    else:
      probs = [n / tot for n in num]
    responsibilities.append(probs)
  return responsibilities



def m_step(data, responsibilities, components):
    n = len(data)
    k = len(components)

    for i in range(k):
        r_i = [resp[i] for resp in responsibilities]
        total_r = sum(r_i)
        components[i]["pi"] = total_r / n if total_r > 0 else 1e-6

        spec_data = [x * r for x, r in zip(data, r_i)]

        name = components[i]["distr name"]

        if name == "Uniform":
          if np.sum(r_i) > 0:
              x_array = np.array(data)
              r_array = np.array(r_i)
              # Filter to data with reasonably high responsibility (e.g., top 80%)
              cutoff = np.percentile(r_array, 80)
              relevant_data = x_array[r_array >= cutoff]
              if len(relevant_data) >= 2:
                  a_est = np.min(relevant_data)
                  b_est = np.max(relevant_data)
              else:
                  # Fallback in case too few data points
                  a_est = np.min(x_array)
                  b_est = np.max(x_array)
              components[i]["params"] = (a_est, b_est)
          else:
              pass # Keep previous parameters if no data points assigned to this component

        elif components[i]["distr name"] == "Exponential":
            if total_r > 0:
                theta = sum(spec_data) / total_r
                components[i]["params"] = (theta,)
            else:
                pass # Keep previous parameters if no data points assigned to this component

        elif components[i]["distr name"] == "Normal":
            if total_r > 0:
                mu = sum(spec_data) / total_r
                var = sum(r * ((x - mu)**2) for x, r in zip(data, r_i)) / total_r
                sigma = math.sqrt(var)
                components[i]["params"] = (mu, sigma)
            else:
                pass # Keep previous parameters if no data points assigned to this component

        elif components[i]["distr name"] == "Bernoulli":
            if total_r > 0:
                p = sum(spec_data) / total_r
                components[i]["params"] = (p,)
            else:
                pass # Keep previous parameters if no data points assigned to this component

        elif components[i]["distr name"] == "Poisson":
            if total_r > 0:
                lambda_ = sum(spec_data) / total_r
                components[i]["params"] = (lambda_,)
            else:
                pass # Keep previous parameters if no data points assigned to this component
        elif components[i]["distr name"] == "Binomial":

            n_old, p = components[i]["params"]
            n_int = int(n_old)  # fixed initial n

            total_r = sum(r_i)
            if total_r > 0:
              weighted_sum = sum(x * r for x, r in zip(data, r_i))
              p_estimate = weighted_sum / (n_int * total_r)
              p_estimate = max(1e-6, min(1 - 1e-6, p_estimate))
              components[i]["params"] = (n_int, p_estimate)
            else:
                pass # Keep previous parameters if no data points assigned to this component
        else:
            raise ValueError(f"Unknown distribution name: {components[i]['distr name']}")


    update_pdfs(components)
    return components


def compute_log_likelihood(data, components):
    log_likelihood = 0
    for x in data:
        mixture_prob = sum(comp['pi'] * comp['pdf'](x) for comp in components)
        if mixture_prob > 0:
            log_likelihood += np.log(mixture_prob)
    return log_likelihood


def EM_MCMC(data, num_iters):

  components = []

  # data = [0, 1, 8, 6, 2, 4] # Removed hardcoded data

  num_components = int(input("How many distributions would you like to mix? "))

  components = []
  for i in range(num_components):
    distr = ''
    while distr not in ["Uniform", "Exponential", "Normal", "Poisson", "Bernoulli", "Binomial"]:
      distr = input(f"Choose distribution {i+1}: ")
    pdf_f, param = pick_distribution(distr)
    components.append({"distr name": distr, "pdf": pdf_f, "params": param, "pi": 1 / num_components}) # --> Start by assuming that each data point has equal
                                                                                                          # chance of being associated with one of the distributions.
  ll_list = []
  for i in range(num_iters):
    responsibilities = e_step(data, components)
    components = m_step(data, responsibilities, components)

    ll = compute_log_likelihood(data, components)
    ll_list.append(ll)
    if i > 0:
      print(f"Iteration {i+1}: Log-likelihood = {ll}")

  # plot log likelihood changes
  plt.figure(figsize=(10, 6))
  plt.scatter(range(len(ll_list)), ll_list, label='Data')

  coeffs = np.polyfit(range(len(ll_list)), ll_list, deg=3)
  trendline = np.poly1d(coeffs)

  plt.plot(range(len(ll_list)), trendline(range(len(ll_list))), color='blue', label='Trendline')

  plt.xlabel("iteration")
  plt.ylabel("log likelihood")
  plt.legend()
  plt.show()

  print("Final parameters:")

  for i in range(len(components)):
    print(f"Component {i+1}: {components[i]['distr name']}")
    print("Parameters:", *(float(x) for x in components[i]['params']))
    print(f"Weight: {float(components[i]['pi'])}")
    print()
  return

np.random.seed(924)

# Generate data
n = 300
data = []

# 40% Normal(2, 0.5)
data += list(np.random.normal(loc=2, scale=0.5, size=int(0.4 * n)))

#data += list(np.random.poisson(3, size=int(0.4 * n)))
#data += list(np.random.binomial(300, 0.5, size=int(0.6 * n)))

# 30% Uniform(0,5)
data += list(np.random.uniform(0,5, size=int(0.3 * n)))

# 30% Exponential(1.5)
data += list(np.random.exponential(scale=1.5, size=int(0.3 * n)))


random.shuffle(data)


EM_MCMC(data, 200)
# Out:
# How many distributions would you like to mix? 3
# Choose distribution 1: Normal
# Enter the mean guess: 5
# Enter the standard deviation guess: 4
# Choose distribution 2: Uniform
# Initial lower bound guess: 2
# Initial upper bound guess: 4
# Choose distribution 3: Exponential
# Enter the mean guess: 3
# Iteration 2: Log-likelihood = -488.3630557982744
# Iteration 3: Log-likelihood = -478.68587843999586
# Iteration 4: Log-likelihood = -472.71348336974427
# Iteration 5: Log-likelihood = -468.76483825147926
# Iteration 6: Log-likelihood = -466.24215825657683
# Iteration 7: Log-likelihood = -464.6959002365311
# Iteration 8: Log-likelihood = -463.76194867875165
# Iteration 9: Log-likelihood = -463.18111609301576
# Iteration 10: Log-likelihood = -462.7878172867443
# Iteration 11: Log-likelihood = -462.485251568746
# Iteration 12: Log-likelihood = -462.22227324901706
# Iteration 13: Log-likelihood = -461.9755267970471
# Iteration 14: Log-likelihood = -461.73712458385745
# Iteration 15: Log-likelihood = -461.50697758732525
# Iteration 16: Log-likelihood = -461.2883378001329
# Iteration 17: Log-likelihood = -461.0852796130674
# Iteration 18: Log-likelihood = -460.9013158764188
# Iteration 19: Log-likelihood = -460.73872425876345
# Iteration 20: Log-likelihood = -460.5983532104975
# Iteration 21: Log-likelihood = -460.479744763866
# Iteration 22: Log-likelihood = -460.3814340277036
# Iteration 23: Log-likelihood = -460.3013083379059
# Iteration 24: Log-likelihood = -460.2369429781825
# Iteration 25: Log-likelihood = -460.18586786015516
# Iteration 26: Log-likelihood = -460.1457510119245
# Iteration 27: Log-likelihood = -460.11450534713487
# Iteration 28: Log-likelihood = -460.09033515477716
# Iteration 29: Log-likelihood = -460.0717409449736
# Iteration 30: Log-likelihood = -460.0574990815849
# Iteration 31: Log-likelihood = -460.04662869541545
# Iteration 32: Log-likelihood = -460.03835434584977
# Iteration 33: Log-likelihood = -460.0320695626225
# Iteration 34: Log-likelihood = -460.0273039695104
# Iteration 35: Log-likelihood = -460.0236950914163
# Iteration 36: Log-likelihood = -460.02096498968086
# Iteration 37: Log-likelihood = -460.0189013617253
# Iteration 38: Log-likelihood = -460.01734251827327
# Iteration 39: Log-likelihood = -460.01616559616025
# Iteration 40: Log-likelihood = -460.01527739841634
# Iteration 41: Log-likelihood = -460.0146073269958
# Iteration 42: Log-likelihood = -460.01410195943873
# Iteration 43: Log-likelihood = -460.0137209039366
# Iteration 44: Log-likelihood = -460.01343364116354
# Iteration 45: Log-likelihood = -460.01321712357
# Iteration 46: Log-likelihood = -460.01305395371895
# Iteration 47: Log-likelihood = -460.0129310038973
# Iteration 48: Log-likelihood = -460.01283837122935
# Iteration 49: Log-likelihood = -460.0127685874158
# Iteration 50: Log-likelihood = -460.01271602145204
# Iteration 51: Log-likelihood = -460.01267642844795
# Iteration 52: Log-likelihood = -460.01264660896373
# Iteration 53: Log-likelihood = -460.01262415189274
# Iteration 54: Log-likelihood = -460.0126072404534
# Iteration 55: Log-likelihood = -460.0125945058565
# Iteration 56: Log-likelihood = -460.01258491693795
# Iteration 57: Log-likelihood = -460.0125776969594
# Iteration 58: Log-likelihood = -460.0125722608749
# Iteration 59: Log-likelihood = -460.01256816805846
# Iteration 60: Log-likelihood = -460.01256508667603
# Iteration 61: Log-likelihood = -460.0125627668379
# Iteration 62: Log-likelihood = -460.01256102037235
# Iteration 63: Log-likelihood = -460.0125597055912
# Iteration 64: Log-likelihood = -460.01255871581014
# Iteration 65: Log-likelihood = -460.01255797070394
# Iteration 66: Log-likelihood = -460.01255740979656
# Iteration 67: Log-likelihood = -460.01255698755773
# Iteration 68: Log-likelihood = -460.012556669708
# Iteration 69: Log-likelihood = -460.01255643044215
# Iteration 70: Log-likelihood = -460.0125562503335
# Iteration 71: Log-likelihood = -460.01255611475585
# Iteration 72: Log-likelihood = -460.01255601269975
# Iteration 73: Log-likelihood = -460.0125559358789
# Iteration 74: Log-likelihood = -460.0125558780515
# Iteration 75: Log-likelihood = -460.0125558345234
# Iteration 76: Log-likelihood = -460.0125558017586
# Iteration 77: Log-likelihood = -460.01255577709486
# Iteration 78: Log-likelihood = -460.01255575853037
# Iteration 79: Log-likelihood = -460.0125557445559
# Iteration 80: Log-likelihood = -460.01255573403694
# Iteration 81: Log-likelihood = -460.012555726119
# Iteration 82: Log-likelihood = -460.0125557201594
# Iteration 83: Log-likelihood = -460.0125557156732
# Iteration 84: Log-likelihood = -460.01255571229655
# Iteration 85: Log-likelihood = -460.0125557097548
# Iteration 86: Log-likelihood = -460.0125557078413
# Iteration 87: Log-likelihood = -460.0125557064012
# Iteration 88: Log-likelihood = -460.01255570531697
# Iteration 89: Log-likelihood = -460.0125557045011
# Iteration 90: Log-likelihood = -460.0125557038869
# Iteration 91: Log-likelihood = -460.012555703425
# Iteration 92: Log-likelihood = -460.0125557030767
# Iteration 93: Log-likelihood = -460.012555702815
# Iteration 94: Log-likelihood = -460.0125557026178
# Iteration 95: Log-likelihood = -460.01255570246957
# Iteration 96: Log-likelihood = -460.0125557023573
# Iteration 97: Log-likelihood = -460.0125557022734
# Iteration 98: Log-likelihood = -460.0125557022098
# Iteration 99: Log-likelihood = -460.0125557021627
# Iteration 100: Log-likelihood = -460.0125557021267
# Iteration 101: Log-likelihood = -460.01255570209986
# Iteration 102: Log-likelihood = -460.0125557020792
# Iteration 103: Log-likelihood = -460.01255570206393
# Iteration 104: Log-likelihood = -460.01255570205245
# Iteration 105: Log-likelihood = -460.01255570204387
# Iteration 106: Log-likelihood = -460.0125557020376
# Iteration 107: Log-likelihood = -460.01255570203296
# Iteration 108: Log-likelihood = -460.012555702029
# Iteration 109: Log-likelihood = -460.01255570202596
# Iteration 110: Log-likelihood = -460.0125557020236
# Iteration 111: Log-likelihood = -460.01255570202227
# Iteration 112: Log-likelihood = -460.0125557020212
# Iteration 113: Log-likelihood = -460.01255570202017
# Iteration 114: Log-likelihood = -460.01255570201954
# Iteration 115: Log-likelihood = -460.0125557020195
# Iteration 116: Log-likelihood = -460.01255570201846
# Iteration 117: Log-likelihood = -460.0125557020185
# Iteration 118: Log-likelihood = -460.01255570201846
# Iteration 119: Log-likelihood = -460.01255570201806
# Iteration 120: Log-likelihood = -460.01255570201783
# Iteration 121: Log-likelihood = -460.01255570201795
# Iteration 122: Log-likelihood = -460.0125557020181
# Iteration 123: Log-likelihood = -460.01255570201766
# Iteration 124: Log-likelihood = -460.0125557020177
# Iteration 125: Log-likelihood = -460.01255570201766
# Iteration 126: Log-likelihood = -460.0125557020175
# Iteration 127: Log-likelihood = -460.01255570201766
# Iteration 128: Log-likelihood = -460.0125557020175
# Iteration 129: Log-likelihood = -460.0125557020175
# Iteration 130: Log-likelihood = -460.01255570201766
# Iteration 131: Log-likelihood = -460.01255570201744
# Iteration 132: Log-likelihood = -460.0125557020175
# Iteration 133: Log-likelihood = -460.01255570201766
# Iteration 134: Log-likelihood = -460.01255570201755
# Iteration 135: Log-likelihood = -460.0125557020173
# Iteration 136: Log-likelihood = -460.0125557020174
# Iteration 137: Log-likelihood = -460.0125557020174
# Iteration 138: Log-likelihood = -460.01255570201795
# Iteration 139: Log-likelihood = -460.01255570201766
# Iteration 140: Log-likelihood = -460.01255570201727
# Iteration 141: Log-likelihood = -460.01255570201715
# Iteration 142: Log-likelihood = -460.01255570201744
# Iteration 143: Log-likelihood = -460.0125557020176
# Iteration 144: Log-likelihood = -460.0125557020177
# Iteration 145: Log-likelihood = -460.0125557020177
# Iteration 146: Log-likelihood = -460.0125557020177
# Iteration 147: Log-likelihood = -460.01255570201783
# Iteration 148: Log-likelihood = -460.01255570201727
# Iteration 149: Log-likelihood = -460.0125557020179
# Iteration 150: Log-likelihood = -460.0125557020178
# Iteration 151: Log-likelihood = -460.01255570201766
# Iteration 152: Log-likelihood = -460.01255570201783
# Iteration 153: Log-likelihood = -460.0125557020182
# Iteration 154: Log-likelihood = -460.01255570201795
# Iteration 155: Log-likelihood = -460.01255570201744
# Iteration 156: Log-likelihood = -460.01255570201744
# Iteration 157: Log-likelihood = -460.0125557020175
# Iteration 158: Log-likelihood = -460.0125557020172
# Iteration 159: Log-likelihood = -460.0125557020175
# Iteration 160: Log-likelihood = -460.0125557020172
# Iteration 161: Log-likelihood = -460.01255570201715
# Iteration 162: Log-likelihood = -460.0125557020176
# Iteration 163: Log-likelihood = -460.0125557020175
# Iteration 164: Log-likelihood = -460.01255570201755
# Iteration 165: Log-likelihood = -460.0125557020174
# Iteration 166: Log-likelihood = -460.0125557020175
# Iteration 167: Log-likelihood = -460.0125557020176
# Iteration 168: Log-likelihood = -460.01255570201727
# Iteration 169: Log-likelihood = -460.01255570201727
# Iteration 170: Log-likelihood = -460.0125557020175
# Iteration 171: Log-likelihood = -460.0125557020176
# Iteration 172: Log-likelihood = -460.0125557020174
# Iteration 173: Log-likelihood = -460.01255570201744
# Iteration 174: Log-likelihood = -460.0125557020178
# Iteration 175: Log-likelihood = -460.01255570201755
# Iteration 176: Log-likelihood = -460.0125557020173
# Iteration 177: Log-likelihood = -460.01255570201766
# Iteration 178: Log-likelihood = -460.0125557020175
# Iteration 179: Log-likelihood = -460.01255570201755
# Iteration 180: Log-likelihood = -460.01255570201766
# Iteration 181: Log-likelihood = -460.0125557020181
# Iteration 182: Log-likelihood = -460.0125557020175
# Iteration 183: Log-likelihood = -460.01255570201755
# Iteration 184: Log-likelihood = -460.01255570201727
# Iteration 185: Log-likelihood = -460.0125557020179
# Iteration 186: Log-likelihood = -460.01255570201766
# Iteration 187: Log-likelihood = -460.0125557020176
# Iteration 188: Log-likelihood = -460.01255570201806
# Iteration 189: Log-likelihood = -460.0125557020175
# Iteration 190: Log-likelihood = -460.01255570201755
# Iteration 191: Log-likelihood = -460.01255570201744
# Iteration 192: Log-likelihood = -460.01255570201783
# Iteration 193: Log-likelihood = -460.01255570201766
# Iteration 194: Log-likelihood = -460.0125557020176
# Iteration 195: Log-likelihood = -460.0125557020175
# Iteration 196: Log-likelihood = -460.0125557020177
# Iteration 197: Log-likelihood = -460.0125557020173
# Iteration 198: Log-likelihood = -460.0125557020175
# Iteration 199: Log-likelihood = -460.0125557020178
# Iteration 200: Log-likelihood = -460.01255570201755
# Final parameters:
# Component 1: Normal
# Parameters: 1.9231091152201019 0.46702082232912245
# Weight: 0.38419247237101944
#
# Component 2: Uniform
# Parameters: 2.499247930559897 3.9503187572319263
# Weight: 0.07732590394500226
#
# Component 3: Exponential
# Parameters: 1.856736895184048
# Weight: 0.5384816236839779

# %% [markdown]
# New NEW NEW

# %%
# Out:
# How many distributions would you like to mix? 3
# Choose distribution 1: Normal
# Enter the mean guess: 3
# Enter the standard deviation guess: 0.7
# Choose distribution 2: 2
# Choose distribution 2: 6
# Choose distribution 2: Uniform
# Initial lower bound guess: 1
# Initial upper bound guess: 7
# Choose distribution 3: Exponential
# Enter the mean guess: 1.7
# Component 0: Normal, count = 8535
# Component 1: Uniform, count = 7878
# Component 2: Exponential, count = 13587
#
# Component 0: Normal, count = 8989
# Component 1: Uniform, count = 7442
# Component 2: Exponential, count = 13569
#
# Iteration 2: Log-likelihood = -463.37273088471215
# Component 0: Normal, count = 9900
# Component 1: Uniform, count = 6986
# Component 2: Exponential, count = 13114
#
# Iteration 3: Log-likelihood = -457.8961545807371
# Component 0: Normal, count = 10871
# Component 1: Uniform, count = 6727
# Component 2: Exponential, count = 12402
#
# Iteration 4: Log-likelihood = -454.21448888434827
# Component 0: Normal, count = 11601
# Component 1: Uniform, count = 6500
# Component 2: Exponential, count = 11899
#
# Iteration 5: Log-likelihood = -452.57593014615065
# Component 0: Normal, count = 12094
# Component 1: Uniform, count = 6406
# Component 2: Exponential, count = 11500
#
# Iteration 6: Log-likelihood = -451.76813907199664
# Component 0: Normal, count = 12550
# Component 1: Uniform, count = 6326
# Component 2: Exponential, count = 11124
#
# Iteration 7: Log-likelihood = -451.38464389662846
# Component 0: Normal, count = 12792
# Component 1: Uniform, count = 6372
# Component 2: Exponential, count = 10836
#
# Iteration 8: Log-likelihood = -451.1717094677383
# Component 0: Normal, count = 13180
# Component 1: Uniform, count = 6335
# Component 2: Exponential, count = 10485
#
# Iteration 9: Log-likelihood = -451.06661322176245
# Component 0: Normal, count = 13139
# Component 1: Uniform, count = 6358
# Component 2: Exponential, count = 10503
#
# Iteration 10: Log-likelihood = -451.0590697006842
# Component 0: Normal, count = 13204
# Component 1: Uniform, count = 6476
# Component 2: Exponential, count = 10320
#
# Iteration 11: Log-likelihood = -450.9675756819019
# Component 0: Normal, count = 13249
# Component 1: Uniform, count = 6580
# Component 2: Exponential, count = 10171
#
# Iteration 12: Log-likelihood = -450.934979107983
# Component 0: Normal, count = 13289
# Component 1: Uniform, count = 6581
# Component 2: Exponential, count = 10130
#
# Iteration 13: Log-likelihood = -450.94434385032235
# Component 0: Normal, count = 13462
# Component 1: Uniform, count = 6626
# Component 2: Exponential, count = 9912
#
# Iteration 14: Log-likelihood = -450.89059572931615
# Component 0: Normal, count = 13565
# Component 1: Uniform, count = 6665
# Component 2: Exponential, count = 9770
#
# Iteration 15: Log-likelihood = -450.8442883184512
# Component 0: Normal, count = 13654
# Component 1: Uniform, count = 6672
# Component 2: Exponential, count = 9674
#
# Iteration 16: Log-likelihood = -450.82194052993475
# Component 0: Normal, count = 13626
# Component 1: Uniform, count = 6753
# Component 2: Exponential, count = 9621
#
# Iteration 17: Log-likelihood = -450.84237853023154
# Component 0: Normal, count = 13642
# Component 1: Uniform, count = 6729
# Component 2: Exponential, count = 9629
#
# Iteration 18: Log-likelihood = -450.8405549670731
# Component 0: Normal, count = 13766
# Component 1: Uniform, count = 6720
# Component 2: Exponential, count = 9514
#
# Iteration 19: Log-likelihood = -450.83362188722646
# Component 0: Normal, count = 13724
# Component 1: Uniform, count = 6752
# Component 2: Exponential, count = 9524
#
# Iteration 20: Log-likelihood = -450.8197593427445
# Component 0: Normal, count = 13887
# Component 1: Uniform, count = 6688
# Component 2: Exponential, count = 9425
#
# Iteration 21: Log-likelihood = -450.8134052268218
# Component 0: Normal, count = 13803
# Component 1: Uniform, count = 6869
# Component 2: Exponential, count = 9328
#
# Iteration 22: Log-likelihood = -450.803092000268
# Component 0: Normal, count = 13791
# Component 1: Uniform, count = 6936
# Component 2: Exponential, count = 9273
#
# Iteration 23: Log-likelihood = -450.80029450249003
# Component 0: Normal, count = 13804
# Component 1: Uniform, count = 6977
# Component 2: Exponential, count = 9219
#
# Iteration 24: Log-likelihood = -450.8288059664695
# Component 0: Normal, count = 13776
# Component 1: Uniform, count = 6949
# Component 2: Exponential, count = 9275
#
# Iteration 25: Log-likelihood = -450.8131235421759
# Component 0: Normal, count = 13869
# Component 1: Uniform, count = 6947
# Component 2: Exponential, count = 9184
#
# Iteration 26: Log-likelihood = -450.82375267632074
# Component 0: Normal, count = 13886
# Component 1: Uniform, count = 6966
# Component 2: Exponential, count = 9148
#
# Iteration 27: Log-likelihood = -450.81658092057023
# Component 0: Normal, count = 13890
# Component 1: Uniform, count = 6941
# Component 2: Exponential, count = 9169
#
# Iteration 28: Log-likelihood = -450.8058157783694
# Component 0: Normal, count = 13906
# Component 1: Uniform, count = 6956
# Component 2: Exponential, count = 9138
#
# Iteration 29: Log-likelihood = -450.80907261401256
# Component 0: Normal, count = 13999
# Component 1: Uniform, count = 6981
# Component 2: Exponential, count = 9020
#
# Iteration 30: Log-likelihood = -450.77999659609526
# Component 0: Normal, count = 14095
# Component 1: Uniform, count = 6911
# Component 2: Exponential, count = 8994
#
# Iteration 31: Log-likelihood = -450.78057711622057
# Component 0: Normal, count = 14115
# Component 1: Uniform, count = 6876
# Component 2: Exponential, count = 9009
#
# Iteration 32: Log-likelihood = -450.7951241683007
# Component 0: Normal, count = 14018
# Component 1: Uniform, count = 6942
# Component 2: Exponential, count = 9040
#
# Iteration 33: Log-likelihood = -450.8179146428947
# Component 0: Normal, count = 14140
# Component 1: Uniform, count = 6959
# Component 2: Exponential, count = 8901
#
# Iteration 34: Log-likelihood = -450.79994560638863
# Component 0: Normal, count = 14160
# Component 1: Uniform, count = 6917
# Component 2: Exponential, count = 8923
#
# Iteration 35: Log-likelihood = -450.78757820789974
# Component 0: Normal, count = 14192
# Component 1: Uniform, count = 6893
# Component 2: Exponential, count = 8915
#
# Iteration 36: Log-likelihood = -450.8139324060233
# Component 0: Normal, count = 14134
# Component 1: Uniform, count = 6925
# Component 2: Exponential, count = 8941
#
# Iteration 37: Log-likelihood = -450.7876426665038
# Component 0: Normal, count = 14073
# Component 1: Uniform, count = 6917
# Component 2: Exponential, count = 9010
#
# Iteration 38: Log-likelihood = -450.7738545872019
# Component 0: Normal, count = 14038
# Component 1: Uniform, count = 6967
# Component 2: Exponential, count = 8995
#
# Iteration 39: Log-likelihood = -450.79443808265336
# Component 0: Normal, count = 14162
# Component 1: Uniform, count = 6970
# Component 2: Exponential, count = 8868
#
# Iteration 40: Log-likelihood = -450.7886916251435
# Component 0: Normal, count = 14116
# Component 1: Uniform, count = 6945
# Component 2: Exponential, count = 8939
#
# Iteration 41: Log-likelihood = -450.7546879513877
# Component 0: Normal, count = 14176
# Component 1: Uniform, count = 6954
# Component 2: Exponential, count = 8870
#
# Iteration 42: Log-likelihood = -450.78479380163884
# Component 0: Normal, count = 14184
# Component 1: Uniform, count = 6998
# Component 2: Exponential, count = 8818
#
# Iteration 43: Log-likelihood = -450.7603751882887
# Component 0: Normal, count = 14150
# Component 1: Uniform, count = 7015
# Component 2: Exponential, count = 8835
#
# Iteration 44: Log-likelihood = -450.78152985662524
# Component 0: Normal, count = 14110
# Component 1: Uniform, count = 7040
# Component 2: Exponential, count = 8850
#
# Iteration 45: Log-likelihood = -450.7905201326525
# Component 0: Normal, count = 14212
# Component 1: Uniform, count = 6876
# Component 2: Exponential, count = 8912
#
# Iteration 46: Log-likelihood = -450.80660540591487
# Component 0: Normal, count = 14127
# Component 1: Uniform, count = 6971
# Component 2: Exponential, count = 8902
#
# Iteration 47: Log-likelihood = -450.80770451385297
# Component 0: Normal, count = 14014
# Component 1: Uniform, count = 6959
# Component 2: Exponential, count = 9027
#
# Iteration 48: Log-likelihood = -450.7807887591217
# Component 0: Normal, count = 14233
# Component 1: Uniform, count = 6815
# Component 2: Exponential, count = 8952
#
# Iteration 49: Log-likelihood = -450.80321987038076
# Component 0: Normal, count = 14233
# Component 1: Uniform, count = 6799
# Component 2: Exponential, count = 8968
#
# Iteration 50: Log-likelihood = -450.78702732437085
# Component 0: Normal, count = 14209
# Component 1: Uniform, count = 6832
# Component 2: Exponential, count = 8959
#
# Iteration 51: Log-likelihood = -450.7941939615385
# Component 0: Normal, count = 14188
# Component 1: Uniform, count = 6807
# Component 2: Exponential, count = 9005
#
# Iteration 52: Log-likelihood = -450.8241405336416
# Component 0: Normal, count = 14160
# Component 1: Uniform, count = 6717
# Component 2: Exponential, count = 9123
#
# Iteration 53: Log-likelihood = -450.8590604643582
# Component 0: Normal, count = 14118
# Component 1: Uniform, count = 6718
# Component 2: Exponential, count = 9164
#
# Iteration 54: Log-likelihood = -450.82432980735814
# Component 0: Normal, count = 14027
# Component 1: Uniform, count = 6742
# Component 2: Exponential, count = 9231
#
# Iteration 55: Log-likelihood = -450.81767934338706
# Component 0: Normal, count = 14038
# Component 1: Uniform, count = 6789
# Component 2: Exponential, count = 9173
#
# Iteration 56: Log-likelihood = -450.8090569825201
# Component 0: Normal, count = 14049
# Component 1: Uniform, count = 6788
# Component 2: Exponential, count = 9163
#
# Iteration 57: Log-likelihood = -450.80555972956927
# Component 0: Normal, count = 13969
# Component 1: Uniform, count = 6794
# Component 2: Exponential, count = 9237
#
# Iteration 58: Log-likelihood = -450.8381660080012
# Component 0: Normal, count = 13928
# Component 1: Uniform, count = 6812
# Component 2: Exponential, count = 9260
#
# Iteration 59: Log-likelihood = -450.8081738800086
# Component 0: Normal, count = 14053
# Component 1: Uniform, count = 6802
# Component 2: Exponential, count = 9145
#
# Iteration 60: Log-likelihood = -450.7944790620982
# Component 0: Normal, count = 14129
# Component 1: Uniform, count = 6769
# Component 2: Exponential, count = 9102
#
# Iteration 61: Log-likelihood = -450.80472563008306
# Component 0: Normal, count = 14137
# Component 1: Uniform, count = 6789
# Component 2: Exponential, count = 9074
#
# Iteration 62: Log-likelihood = -450.810605186604
# Component 0: Normal, count = 14140
# Component 1: Uniform, count = 6838
# Component 2: Exponential, count = 9022
#
# Iteration 63: Log-likelihood = -450.8190802813565
# Component 0: Normal, count = 14283
# Component 1: Uniform, count = 6822
# Component 2: Exponential, count = 8895
#
# Iteration 64: Log-likelihood = -450.84856413042536
# Component 0: Normal, count = 14360
# Component 1: Uniform, count = 6836
# Component 2: Exponential, count = 8804
#
# Iteration 65: Log-likelihood = -450.84935960661
# Component 0: Normal, count = 14451
# Component 1: Uniform, count = 6777
# Component 2: Exponential, count = 8772
#
# Iteration 66: Log-likelihood = -450.8385024334908
# Component 0: Normal, count = 14341
# Component 1: Uniform, count = 6811
# Component 2: Exponential, count = 8848
#
# Iteration 67: Log-likelihood = -450.79921102471786
# Component 0: Normal, count = 14292
# Component 1: Uniform, count = 6891
# Component 2: Exponential, count = 8817
#
# Iteration 68: Log-likelihood = -450.7855228178591
# Component 0: Normal, count = 14154
# Component 1: Uniform, count = 6993
# Component 2: Exponential, count = 8853
#
# Iteration 69: Log-likelihood = -450.8051962496774
# Component 0: Normal, count = 14265
# Component 1: Uniform, count = 6929
# Component 2: Exponential, count = 8806
#
# Iteration 70: Log-likelihood = -450.7875282636262
# Component 0: Normal, count = 14223
# Component 1: Uniform, count = 6971
# Component 2: Exponential, count = 8806
#
# Iteration 71: Log-likelihood = -450.76971139547453
# Component 0: Normal, count = 14099
# Component 1: Uniform, count = 7061
# Component 2: Exponential, count = 8840
#
# Iteration 72: Log-likelihood = -450.75065871938284
# Component 0: Normal, count = 14221
# Component 1: Uniform, count = 7047
# Component 2: Exponential, count = 8732
#
# Iteration 73: Log-likelihood = -450.7593420217082
# Component 0: Normal, count = 14322
# Component 1: Uniform, count = 6939
# Component 2: Exponential, count = 8739
#
# Iteration 74: Log-likelihood = -450.78824198062273
# Component 0: Normal, count = 14357
# Component 1: Uniform, count = 6993
# Component 2: Exponential, count = 8650
#
# Iteration 75: Log-likelihood = -450.7865461694629
# Component 0: Normal, count = 14270
# Component 1: Uniform, count = 7019
# Component 2: Exponential, count = 8711
#
# Iteration 76: Log-likelihood = -450.7717721933567
# Component 0: Normal, count = 14212
# Component 1: Uniform, count = 7007
# Component 2: Exponential, count = 8781
#
# Iteration 77: Log-likelihood = -450.7627113304905
# Component 0: Normal, count = 14157
# Component 1: Uniform, count = 7058
# Component 2: Exponential, count = 8785
#
# Iteration 78: Log-likelihood = -450.743629262126
# Component 0: Normal, count = 14039
# Component 1: Uniform, count = 7049
# Component 2: Exponential, count = 8912
#
# Iteration 79: Log-likelihood = -450.75173395314096
# Component 0: Normal, count = 13832
# Component 1: Uniform, count = 7143
# Component 2: Exponential, count = 9025
#
# Iteration 80: Log-likelihood = -450.78666554183025
# Component 0: Normal, count = 13933
# Component 1: Uniform, count = 7084
# Component 2: Exponential, count = 8983
#
# Iteration 81: Log-likelihood = -450.803096870832
# Component 0: Normal, count = 14069
# Component 1: Uniform, count = 6954
# Component 2: Exponential, count = 8977
#
# Iteration 82: Log-likelihood = -450.7642111943141
# Component 0: Normal, count = 14089
# Component 1: Uniform, count = 6913
# Component 2: Exponential, count = 8998
#
# Iteration 83: Log-likelihood = -450.7735002529543
# Component 0: Normal, count = 14226
# Component 1: Uniform, count = 6852
# Component 2: Exponential, count = 8922
#
# Iteration 84: Log-likelihood = -450.78523839187176
# Component 0: Normal, count = 14126
# Component 1: Uniform, count = 6940
# Component 2: Exponential, count = 8934
#
# Iteration 85: Log-likelihood = -450.76159835678135
# Component 0: Normal, count = 14015
# Component 1: Uniform, count = 6914
# Component 2: Exponential, count = 9071
#
# Iteration 86: Log-likelihood = -450.7851700414704
# Component 0: Normal, count = 14005
# Component 1: Uniform, count = 6903
# Component 2: Exponential, count = 9092
#
# Iteration 87: Log-likelihood = -450.7674260803382
# Component 0: Normal, count = 14035
# Component 1: Uniform, count = 6968
# Component 2: Exponential, count = 8997
#
# Iteration 88: Log-likelihood = -450.76760911366426
# Component 0: Normal, count = 13995
# Component 1: Uniform, count = 6991
# Component 2: Exponential, count = 9014
#
# Iteration 89: Log-likelihood = -450.7851749079656
# Component 0: Normal, count = 14025
# Component 1: Uniform, count = 6920
# Component 2: Exponential, count = 9055
#
# Iteration 90: Log-likelihood = -450.78654419458843
# Component 0: Normal, count = 14102
# Component 1: Uniform, count = 6763
# Component 2: Exponential, count = 9135
#
# Iteration 91: Log-likelihood = -450.79470907355415
# Component 0: Normal, count = 14037
# Component 1: Uniform, count = 6758
# Component 2: Exponential, count = 9205
#
# Iteration 92: Log-likelihood = -450.8183366372009
# Component 0: Normal, count = 13956
# Component 1: Uniform, count = 6846
# Component 2: Exponential, count = 9198
#
# Iteration 93: Log-likelihood = -450.79591098080795
# Component 0: Normal, count = 14014
# Component 1: Uniform, count = 6867
# Component 2: Exponential, count = 9119
#
# Iteration 94: Log-likelihood = -450.78903693041906
# Component 0: Normal, count = 14107
# Component 1: Uniform, count = 6848
# Component 2: Exponential, count = 9045
#
# Iteration 95: Log-likelihood = -450.784927650715
# Component 0: Normal, count = 14123
# Component 1: Uniform, count = 6822
# Component 2: Exponential, count = 9055
#
# Iteration 96: Log-likelihood = -450.83018555402356
# Component 0: Normal, count = 14058
# Component 1: Uniform, count = 6868
# Component 2: Exponential, count = 9074
#
# Iteration 97: Log-likelihood = -450.83391850271323
# Component 0: Normal, count = 14256
# Component 1: Uniform, count = 6830
# Component 2: Exponential, count = 8914
#
# Iteration 98: Log-likelihood = -450.78976977333
# Component 0: Normal, count = 14487
# Component 1: Uniform, count = 6801
# Component 2: Exponential, count = 8712
#
# Iteration 99: Log-likelihood = -450.80418719340645
# Component 0: Normal, count = 14592
# Component 1: Uniform, count = 6739
# Component 2: Exponential, count = 8669
#
# Iteration 100: Log-likelihood = -450.80662632435576
# Final parameters:
# Component 1: Normal
# Parameters: 1.9483326598443473 0.6340512282336651
# Weight: 0.48639999998469335
#
# Component 2: Uniform
# Parameters: 1.0151356270614553 5.728516836438667
# Weight: 0.22463333334420335
#
# Component 3: Exponential
# Parameters: 1.0648916545458067
# Weight: 0.2889666666711033

# %% [markdown]
# # EMMC

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import math
import functools

def pick_distribution(answer):

  #Continuous Distributions-----------------------------------------------------

  if answer == "Uniform":
    while True:
      try:
        a0 = float(input("Initial lower bound guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")
    while True:
      try:
        b0 = float(input("Initial upper bound guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")
    def pdf(x):
      return 1 / (b0 - a0) if a0 <= x <= b0 else 0

    return pdf, (a0, b0)

  if answer == "Exponential":
    while True:
      try:
        theta0 = float(input("Enter the mean guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")

    def pdf(x):
      return (1 / theta0) * math.exp(-x / theta0) if x >= 0 else 0

    return pdf, (theta0,) # Corrected parameter return

  if answer == "Normal":
    while True:
      try:
        mu0 = float(input("Enter the mean guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")
    while True:
      try:
        sigma0 = float(input("Enter the standard deviation guess: "))
        break
      except ValueError:
        print("Invalid input. Please enter a number.")
    def pdf(x_val):
      return (1 / (sigma0 * math.sqrt(2 * math.pi))) * math.exp(-(x_val - mu0)**2 / (2 * sigma0**2))
    return pdf, (mu0, sigma0)


  #Discrete Distributions-----------------------------------------------------

  if answer == "Poisson":

    integer_data = [x for x in data if float(x).is_integer()]
    estimated_lambda = np.mean(integer_data) if integer_data else 3.0

    print(f"Suggested lambda (from integer data): {estimated_lambda:.2f}")
    while True:
        try:
            lambda_val = float(input("Enter the Poisson mean (lambda): "))
            if lambda_val > 0:
                break
            else:
                print("lambda must be greater than 0.")
        except ValueError:
            print("Invalid input. Please enter a number.")
    def pdf(x):
      if x >= 0 and float(x).is_integer():
          x_int = int(x)
          # Use log-likelihood to avoid overflow with large numbers
          log_pdf = -lambda_val + x_int * math.log(lambda_val) - math.lgamma(x_int + 1)
          return math.exp(log_pdf)
      else:
          return 0

    return pdf, (lambda_val,)

  if answer == "Bernoulli":
    while True:
        try:
            p = float(input("Enter probability of success (0 < p < 1): "))
            if 0 < p < 1:
                break
            else:
                print("p must be between 0 and 1.")
        except ValueError:
            print("Invalid input. Please enter a number.")

    def pdf(x):
        return p if x == 1 else (1 - p) if x == 0 else 0

    return pdf, (p,)

  if answer == "Binomial":
    n= 100000000000
    while True:
        try:
            p = float(input("Enter probability of success (0 < p < 1): "))
            if 0 < p < 1:
                break
            else:
                print("0 < p < 1.")
        except ValueError:
            print("Invalid input. Please enter a positive number.")
    def pdf(x):
      if 0 <= x <= n:
          return math.comb(n, x) * (p ** x) * ((1 - p) ** (n - x))
      else:
          return 0

    return pdf, (n, p)

#-------------------------------------------------------------------------------


def e_step_MCMC(data, components, steps = 100):
  n = len(data)
  k = len(components)

  z_samples = []

  for i in range(n):
    x = data[i]

    weights = [comp["pi"] * comp["pdf"](x) for comp in components]
    total = sum(weights)

    if total == 0:
      weights = [1 / k] * k
    else:
      weights = [w / total for w in weights]
    z = np.random.choice(range(k), p=weights)

    chain = []

    for t in range(steps):
      if k > 1: # Add check for k > 1
        z_new = np.random.choice([j for j in range(k) if j != z])

        if components[z_new]["distr name"] in {"Poisson", "Bernoulli", "Binomial"} and not float(x).is_integer():
          chain.append(z)
          continue


        num = components[z_new]["pi"] * components[z_new]["pdf"](x) # Score function which will idealize the data point with a certain distribution if the associated pi and pdf value
        den = components[z]["pi"] * components[z]["pdf"](x)         # with the data point is more than that of the previous

        alpha = min(1, num / den if den > 0 else 1)

        if np.random.rand() < alpha:
          z = z_new

      chain.append(z)

    z_samples.append(chain)

  return z_samples

def m_step_MCMC(z_samples, components):

  n = len(data)
  k = len(components)

  flatz = [z for chain in z_samples for z in chain]

  total = len(flatz)

  eps = 1e-6
  min_weight = 0.05

  for i in range(k):
    count_i = flatz.count(i)
    pi_i = (count_i + eps) / (total)
    components[i]["pi"] =  max(min_weight, pi_i)  # Updates pi / how much each distribution is mixed with how many exposures we got of the the specific distribution for all the data samples / total
                                                 # we give (count_i + e-6) for the case when our samples got us no cases when the data point was associated with pi_i distribution. This would make it so
                                                    # that theres no chance for the distribution to be revived no matter the pdf we got exposed to in the e step.

  new_total = sum(comp["pi"] for comp in components)

  for i in range(k):
    components[i]["pi"] /= new_total # normalizing because of min_weight

  return components

def update_params_pdfs(data, components, z_samples):
  k = len(components)
  n = len(data)

  flat_x = [x for i, x in enumerate(data) for j in range(len(z_samples[i]))]
  flat_z = [z for chain in z_samples for z in chain]

  for i in range(len(components)):
      print(f"Component {i}: {components[i]['distr name']}, count = {flat_z.count(i)}")

  print()

  for i in range(k):

    spec_data  = [x for x, z in zip(flat_x, flat_z) if z == i] # filters data points into what distribution we think the data points are associated with

    if components[i]["distr name"] == "Uniform":
      if spec_data: # Add check for empty list
        components[i]["params"] = (min(spec_data), max(spec_data))
      else:
        pass

    if components[i]["distr name"] == "Exponential":
      if spec_data: # Add check for empty list
        components[i]["params"] = (np.mean(spec_data),)
      else:
        pass

    if components[i]["distr name"] == "Normal":
      if spec_data: # Add check for empty list
        components[i]["params"] = (np.mean(spec_data), np.std(spec_data))
      else:
        pass

    if components[i]["distr name"] == "Bernoulli":
      if spec_data:
        components[i]["params"] = (np.mean(spec_data),)
      else:
        pass

    if components[i]["distr name"] == "Poisson":
      if spec_data:
        components[i]["params"] = (np.mean(spec_data),)
      else:
        pass
    if components[i]["distr name"] == "Binomial":
        if spec_data:
          n_old, p = components[i]["params"]

          n_int = int(n) if isinstance(n, (int, float)) else n

          n = max(n_int, int(np.percentile(spec_data, 95)))

          p_estimate = (np.mean(spec_data) / n_int) if n_int > 0 and np.mean(spec_data) > 0 else 1e-6
          # Ensure p is within (0, 1)
          p_estimate = max(1e-6, min(1 - 1e-6, p_estimate))
          components[i]["params"] = (n_int, p_estimate)
        else:
          pass


  for comp in components:
      name = comp["distr name"]
      params = comp["params"]

      if name == "Normal":
        if len(spec_data) > 5:
          mu, sigma = params
          def f(x, mu=mu, sigma=sigma):
              return (1 / (sigma * math.sqrt(2 * math.pi))) * math.exp(-(x - mu)**2 / (2 * sigma**2))
          comp["pdf"] = f
      elif name == "Poisson":
          lamb = params[0]
          def f(x, lamb=lamb):
              if x >= 0 and float(x).is_integer():
                  x_int = int(x)
                  # Use log-likelihood to avoid overflow with large numbers
                  log_pdf = -lamb + x_int * math.log(lamb) - math.lgamma(x_int + 1)
                  return math.exp(log_pdf)
              else:
                  return 0
          comp["pdf"] = f
      elif name == "Exponential":
          theta = params[0]
          def f(x, theta=theta):
              return (1 / theta) * math.exp(-x / theta) if x >= 0 else 0
          comp["pdf"] = f
      elif name == "Uniform":
          a, b = params
          def f(x, a=a, b=b):
              return 1 / (b - a) if a <= x <= b else 0
          comp["pdf"] = f
      elif name == "Bernoulli":
          p = params[0]
          def f(x, p=p):
              return p if x == 1 else (1 - p) if x == 0 else 0
          comp["pdf"] = f
      elif name == "Binomial":
        n, p = params
        def f(x):
          if 0 <= x <= n:
            return math.comb(n, x) * (p ** x) * ((1 - p) ** (n - x))
          else:
            return 0
        comp["pdf"] = f
      else:
        raise ValueError(f"Unknown distribution name: {name}")
  return components

def compute_log_likelihood(data, components):
    log_likelihood = 0
    for x in data:
        mixture_prob = sum(comp['pi'] * comp['pdf'](x) for comp in components)
        if mixture_prob > 0:
            log_likelihood += np.log(mixture_prob)
    return log_likelihood


def EM_MCMC(data, num_iters):

  components = []

  # data = [0, 1, 8, 6, 2, 4] # Removed hardcoded data

  num_components = int(input("How many distributions would you like to mix? "))

  components = []
  for i in range(num_components):
    distr = ''
    while distr not in ["Uniform", "Exponential", "Normal", "Poisson", "Bernoulli", "Binomial"]:
      distr = input(f"Choose distribution {i+1}: ")
    pdf_f, param = pick_distribution(distr)
    components.append({"distr name": distr, "pdf": pdf_f, "params": param, "pi": 1 / num_components}) # --> Start by assuming that each data point has equal
                                                                                                          # chance of being associated with one of the distributions.
  ll_list = []
  for i in range(num_iters):
    z_samples = e_step_MCMC(data, components) #
    components = m_step_MCMC(z_samples, components)
    components = update_params_pdfs(data, components, z_samples)

    ll = compute_log_likelihood(data, components)
    ll_list.append(ll)
    if i > 0:
      print(f"Iteration {i+1}: Log-likelihood = {ll}")

  # plot log likelihood changes
  plt.figure(figsize=(10, 6))
  plt.scatter(range(len(ll_list)), ll_list, label='Data')

  coeffs = np.polyfit(range(len(ll_list)), ll_list, deg=3)
  trendline = np.poly1d(coeffs)

  plt.plot(range(len(ll_list)), trendline(range(len(ll_list))), color='blue', label='Trendline')

  plt.xlabel("iteration")
  plt.ylabel("log likelihood")
  plt.legend()
  plt.show()

  print("Final parameters:")

  for i in range(len(components)):
    print(f"Component {i+1}: {components[i]['distr name']}")
    print("Parameters:", *(float(x) for x in components[i]['params']))
    print(f"Weight: {float(components[i]['pi'])}")
    print()
  return

np.random.seed(924)

# Generate data
n = 300
data = []

# 40% Normal(2, 0.5)
#data += list(np.random.normal(loc=2, scale=0.5, size=int(0.4 * n)))

data += list(np.random.poisson(3, size=int(0.4 * n)))
data += list(np.random.binomial(300, 0.5, size=int(0.6 * n)))

# 30% Uniform(0,5)
#data += list(np.random.uniform(0,5, size=int(0.3 * n)))

# 30% Exponential(1.5)
#data += list(np.random.exponential(scale=1.5, size=int(0.3 * n)))


random.shuffle(data)


EM_MCMC(data, 20)
